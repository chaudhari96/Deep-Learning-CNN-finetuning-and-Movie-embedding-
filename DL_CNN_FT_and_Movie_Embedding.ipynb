# %% [markdown]
#  ## Deep Learning [IDS 576] : ASSIGNMENT 2
# Aditya Chaudhari [653975298]\

# %% [markdown]
# # Problem 1

# %% [markdown]
# **CNNs and finetuning (4pt)**
#
# Download the CIFAR 10 dataset. Use the pretrained Resnet18 model (from trochvision) to extract features. Use the features as inputs in a new multi-class logistic regression model (use nn.Linear/ nn.Module to define your model)
#
# **PART A :** Describe any choices made and report test performance.
#
# **PART B:** Display the top 5 correct predictions and the top 5 incorrect predictions in each class (show the images and the prediction labels) compactly.

# %% [markdown]
# We made the following choices:
# 1.   Loss Function : Log Loss Cross Entropy
# 2.   Learning Rate : 0.001
# 3.   Momentum : 0.9
# 4.   Scheduler step_size : 7
# 5.   gamma : 0.1
# 6.   num_epochs : 10

# %%
import pickle
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from google.colab import drive
import heapq

drive.mount('/content/drive')
# %cd /content/drive/My Drive/
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Mounted at /content/drive
# /content/drive/My Drive

# %%
# this code was reused from https://github.com/snatch59/load-cifar-10 as coded by Petras Saduikis
def unpickle(file):
    """load the cifar-10 data"""

    with open(file, 'rb') as fo:
        data = pickle.load(fo, encoding='bytes')
    return data


def load_cifar_10_data(data_dir, negatives=False):
    """
    Return train_data, train_filenames, train_labels, test_data, test_filenames, test_labels
    """

    # get the meta_data_dict
    # num_cases_per_batch: 1000
    # label_names: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
    # num_vis: :3072

    meta_data_dict = unpickle(data_dir + "/batches.meta")
    cifar_label_names = meta_data_dict[b'label_names']
    cifar_label_names = np.array(cifar_label_names)

    # training data
    cifar_train_data = None
    cifar_train_filenames = []
    cifar_train_labels = []

    # cifar_train_data_dict
    # 'batch_label': 'training batch 5 of 5'
    # 'data': ndarray
    # 'filenames': list
    # 'labels': list

    for i in range(1, 6):
        cifar_train_data_dict = unpickle(data_dir + "/data_batch_{}".format(i))
        if i == 1:
            cifar_train_data = cifar_train_data_dict[b'data']
        else:
            cifar_train_data = np.vstack((cifar_train_data, cifar_train_data_dict[b'data']))
        cifar_train_filenames += cifar_train_data_dict[b'filenames']
        cifar_train_labels += cifar_train_data_dict[b'labels']

    cifar_train_data = cifar_train_data.reshape((len(cifar_train_data), 3, 32, 32))
    if negatives:
        cifar_train_data = cifar_train_data.transpose(0, 2, 3, 1).astype(np.float32)
    #else:
        #cifar_train_data = np.rollaxis(cifar_train_data, 1, 4)
    cifar_train_filenames = np.array(cifar_train_filenames)
    cifar_train_labels = np.array(cifar_train_labels)

    # test data
    # cifar_test_data_dict
    # 'batch_label': 'testing batch 1 of 1'
    # 'data': ndarray
    # 'filenames': list
    # 'labels': list

    cifar_test_data_dict = unpickle(data_dir + "/test_batch")
    cifar_test_data = cifar_test_data_dict[b'data']
    cifar_test_filenames = cifar_test_data_dict[b'filenames']
    cifar_test_labels = cifar_test_data_dict[b'labels']

    cifar_test_data = cifar_test_data.reshape((len(cifar_test_data), 3, 32, 32))
    if negatives:
        cifar_test_data = cifar_test_data.transpose(0, 2, 3, 1).astype(np.float32)
    #else:
        #cifar_test_data = np.rollaxis(cifar_test_data, 1, 4)
    cifar_test_filenames = np.array(cifar_test_filenames)
    cifar_test_labels = np.array(cifar_test_labels)

    return cifar_train_data, cifar_train_filenames, cifar_train_labels, \
        cifar_test_data, cifar_test_filenames, cifar_test_labels, cifar_label_names

# %%
cifar_10_dir = '/content/drive/My Drive/cifar-10-batches-py'
train_data, train_filenames, train_labels, test_data, test_filenames, test_labels, label_names = \
    load_cifar_10_data(cifar_10_dir)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    dataset_size = train_data.shape[0]

    for epoch in range(num_epochs):
        print('Training Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # training phase
        phase = 'train'
        model.train()  # Set model to training mode
        running_loss = 0.0
        running_corrects = 0

        # Iterate over data. must be from 0 to 500
        for i in range(0, 500):
            print ('running iter='+str(i))
            inputs = train_data[i*100:(i+1)*100:,:]
            labels = train_labels[i*100:(i+1)*100]

            # zero the parameter gradients
            optimizer.zero_grad()

            inputs = torch.from_numpy(inputs)
            labels = torch.from_numpy(labels)

            inputs = inputs.type(torch.FloatTensor)

            # forward
            # track history if only in train
            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                #perform backword and optimize in training
                loss.backward()
                optimizer.step()

            # statistics
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        scheduler.step()   
        epoch_loss = running_loss / dataset_size
        epoch_acc = running_corrects.double() / dataset_size

        print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))             
  
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    return model

##################################################################################

def validate_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    dataset_size = train_data.shape[0]

    # validation phase
    phase = 'Val'
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    # Iterate over data. must be from 0 to 99
    for i in range(0,100):
        print ('running iter='+str(i))
        inputs = test_data[i*100:(i+1)*100:,:]
        labels = test_labels[i*100:(i+1)*100]

        # zero the parameter gradients
        optimizer.zero_grad()

        inputs = torch.from_numpy(inputs)
        labels = torch.from_numpy(labels)

        inputs = inputs.type(torch.FloatTensor)

        # forward
        # track history if only in train
        with torch.set_grad_enabled(phase == 'train'):
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        # statistics
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / dataset_size
        epoch_acc = running_corrects.double() / dataset_size

        print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))             
  
    time_elapsed = time.time() - since
    print('validation complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    return epoch_loss, epoch_acc
#####################################################################################

model_ft = torchvision.models.resnet18(pretrained=True)

for param in model_ft.parameters():
    param.requires_grad = False

num_ftrs = model_ft.fc.in_features
nn.Linear(num_ftrs, 10)
model_ft.fc = nn.Linear(num_ftrs, 10)
model_ft = model_ft.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

trained_model = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,num_epochs=10)
a, b = validate_model(trained_model, criterion, optimizer_ft, exp_lr_scheduler,num_epochs=2)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 1.8503 Acc: 0.3529
# Training Epoch 1/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# running iter=67
# running iter=68
# running iter=69
# running iter=70
# running iter=71
# running iter=72
# running iter=73
# running iter=74
# running iter=75
# running iter=76
# running iter=77
# running iter=78
# running iter=79
# running iter=80
# running iter=81
# running iter=82
# running iter=83
# running iter=84
# running iter=85
# running iter=86
# running iter=87
# running iter=88
# running iter=89
# running iter=90
# running iter=91
# running iter=92
# running iter=93
# running iter=94
# running iter=95
# running iter=96
# running iter=97
# running iter=98
# running iter=99
# running iter=100
# running iter=101
# running iter=102
# running iter=103
# running iter=104
# running iter=105
# running iter=106
# running iter=107
# running iter=108
# running iter=109
# running iter=110
# running iter=111
# running iter=112
# running iter=113
# running iter=114
# running iter=115
# running iter=116
# running iter=117
# running iter=118
# running iter=119
# running iter=120
# running iter=121
# running iter=122
# running iter=123
# running iter=124
# running iter=125
# running iter=126
# running iter=127
# running iter=128
# running iter=129
# running iter=130
# running iter=131
# running iter=132
# running iter=133
# running iter=134
# running iter=135
# running iter=136
# running iter=137
# running iter=138
# running iter=139
# running iter=140
# running iter=141
# running iter=142
# running iter=143
# running iter=144
# running iter=145
# running iter=146
# running iter=147
# running iter=148
# running iter=149
# running iter=150
# running iter=151
# running iter=152
# running iter=153
# running iter=154
# running iter=155
# running iter=156
# running iter=157
# running iter=158
# running iter=159
# running iter=160
# running iter=161
# running iter=162
# running iter=163
# running iter=164
# running iter=165
# running iter=166
# running iter=167
# running iter=168
# running iter=169
# running iter=170
# running iter=171
# running iter=172
# running iter=173
# running iter=174
# running iter=175
# running iter=176
# running iter=177
# running iter=178
# running iter=179
# running iter=180
# running iter=181
# running iter=182
# running iter=183
# running iter=184
# running iter=185
# running iter=186
# running iter=187
# running iter=188
# running iter=189
# running iter=190
# running iter=191
# running iter=192
# running iter=193
# running iter=194
# running iter=195
# running iter=196
# running iter=197
# running iter=198
# running iter=199
# running iter=200
# running iter=201
# running iter=202
# running iter=203
# running iter=204
# running iter=205
# running iter=206
# running iter=207
# running iter=208
# running iter=209
# running iter=210
# running iter=211
# running iter=212
# running iter=213
# running iter=214
# running iter=215
# running iter=216
# running iter=217
# running iter=218
# running iter=219
# running iter=220
# running iter=221
# running iter=222
# running iter=223
# running iter=224
# running iter=225
# running iter=226
# running iter=227
# running iter=228
# running iter=229
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 1.6327 Acc: 0.4339
# Training Epoch 2/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# running iter=67
# running iter=68
# running iter=69
# running iter=70
# running iter=71
# running iter=72
# running iter=73
# running iter=74
# running iter=75
# running iter=76
# running iter=77
# running iter=78
# running iter=79
# running iter=80
# running iter=81
# running iter=82
# running iter=83
# running iter=84
# running iter=85
# running iter=86
# running iter=87
# running iter=88
# running iter=89
# running iter=90
# running iter=91
# running iter=92
# running iter=93
# running iter=94
# running iter=95
# running iter=96
# running iter=97
# running iter=98
# running iter=99
# running iter=100
# running iter=101
# running iter=102
# running iter=103
# running iter=104
# running iter=105
# running iter=106
# running iter=107
# running iter=108
# running iter=109
# running iter=110
# running iter=111
# running iter=112
# running iter=113
# running iter=114
# running iter=115
# running iter=116
# running iter=117
# running iter=118
# running iter=119
# running iter=120
# running iter=121
# running iter=122
# running iter=123
# running iter=124
# running iter=125
# running iter=126
# running iter=127
# running iter=128
# running iter=129
# running iter=130
# running iter=131
# running iter=132
# running iter=133
# running iter=134
# running iter=135
# running iter=136
# running iter=137
# running iter=138
# running iter=139
# running iter=140
# running iter=141
# running iter=142
# running iter=143
# running iter=144
# running iter=145
# running iter=146
# running iter=147
# running iter=148
# running iter=149
# running iter=150
# running iter=151
# running iter=152
# running iter=153
# running iter=154
# running iter=155
# running iter=156
# running iter=157
# running iter=158
# running iter=159
# running iter=160
# running iter=161
# running iter=162
# running iter=163
# running iter=164
# running iter=165
# running iter=166
# running iter=167
# running iter=168
# running iter=169
# running iter=170
# running iter=171
# running iter=172
# running iter=173
# running iter=174
# running iter=175
# running iter=176
# running iter=177
# running iter=178
# running iter=179
# running iter=180
# running iter=181
# running iter=182
# running iter=183
# running iter=184
# running iter=185
# running iter=186
# running iter=187
# running iter=188
# running iter=189
# running iter=190
# running iter=191
# running iter=192
# running iter=193
# running iter=194
# running iter=195
# running iter=196
# running iter=197
# running iter=198
# running iter=199
# running iter=200
# running iter=201
# running iter=202
# running iter=203
# running iter=204
# running iter=205
# running iter=206
# running iter=207
# running iter=208
# running iter=209
# running iter=210
# running iter=211
# running iter=212
# running iter=213
# running iter=214
# running iter=215
# running iter=216
# running iter=217
# running iter=218
# running iter=219
# running iter=220
# running iter=221
# running iter=222
# running iter=223
# running iter=224
# running iter=225
# running iter=226
# running iter=227
# running iter=228
# running iter=229
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 1.5884 Acc: 0.4494
# Training Epoch 3/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# running iter=67
# running iter=68
# running iter=69
# running iter=70
# running iter=71
# running iter=72
# running iter=73
# running iter=74
# running iter=75
# running iter=76
# running iter=77
# running iter=78
# running iter=79
# running iter=80
# running iter=81
# running iter=82
# running iter=83
# running iter=84
# running iter=85
# running iter=86
# running iter=87
# running iter=88
# running iter=89
# running iter=90
# running iter=91
# running iter=92
# running iter=93
# running iter=94
# running iter=95
# running iter=96
# running iter=97
# running iter=98
# running iter=99
# running iter=100
# running iter=101
# running iter=102
# running iter=103
# running iter=104
# running iter=105
# running iter=106
# running iter=107
# running iter=108
# running iter=109
# running iter=110
# running iter=111
# running iter=112
# running iter=113
# running iter=114
# running iter=115
# running iter=116
# running iter=117
# running iter=118
# running iter=119
# running iter=120
# running iter=121
# running iter=122
# running iter=123
# running iter=124
# running iter=125
# running iter=126
# running iter=127
# running iter=128
# running iter=129
# running iter=130
# running iter=131
# running iter=132
# running iter=133
# running iter=134
# running iter=135
# running iter=136
# running iter=137
# running iter=138
# running iter=139
# running iter=140
# running iter=141
# running iter=142
# running iter=143
# running iter=144
# running iter=145
# running iter=146
# running iter=147
# running iter=148
# running iter=149
# running iter=150
# running iter=151
# running iter=152
# running iter=153
# running iter=154
# running iter=155
# running iter=156
# running iter=157
# running iter=158
# running iter=159
# running iter=160
# running iter=161
# running iter=162
# running iter=163
# running iter=164
# running iter=165
# running iter=166
# running iter=167
# running iter=168
# running iter=169
# running iter=170
# running iter=171
# running iter=172
# running iter=173
# running iter=174
# running iter=175
# running iter=176
# running iter=177
# running iter=178
# running iter=179
# running iter=180
# running iter=181
# running iter=182
# running iter=183
# running iter=184
# running iter=185
# running iter=186
# running iter=187
# running iter=188
# running iter=189
# running iter=190
# running iter=191
# running iter=192
# running iter=193
# running iter=194
# running iter=195
# running iter=196
# running iter=197
# running iter=198
# running iter=199
# running iter=200
# running iter=201
# running iter=202
# running iter=203
# running iter=204
# running iter=205
# running iter=206
# running iter=207
# running iter=208
# running iter=209
# running iter=210
# running iter=211
# running iter=212
# running iter=213
# running iter=214
# running iter=215
# running iter=216
# running iter=217
# running iter=218
# running iter=219
# running iter=220
# running iter=221
# running iter=222
# running iter=223
# running iter=224
# running iter=225
# running iter=226
# running iter=227
# running iter=228
# running iter=229
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 1.5660 Acc: 0.4562
# Training Epoch 4/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# running iter=67
# running iter=68
# running iter=69
# running iter=70
# running iter=71
# running iter=72
# running iter=73
# running iter=74
# running iter=75
# running iter=76
# running iter=77
# running iter=78
# running iter=79
# running iter=80
# running iter=81
# running iter=82
# running iter=83
# running iter=84
# running iter=85
# running iter=86
# running iter=87
# running iter=88
# running iter=89
# running iter=90
# running iter=91
# running iter=92
# running iter=93
# running iter=94
# running iter=95
# running iter=96
# running iter=97
# running iter=98
# running iter=99
# running iter=100
# running iter=101
# running iter=102
# running iter=103
# running iter=104
# running iter=105
# running iter=106
# running iter=107
# running iter=108
# running iter=109
# running iter=110
# running iter=111
# running iter=112
# running iter=113
# running iter=114
# running iter=115
# running iter=116
# running iter=117
# running iter=118
# running iter=119
# running iter=120
# running iter=121
# running iter=122
# running iter=123
# running iter=124
# running iter=125
# running iter=126
# running iter=127
# running iter=128
# running iter=129
# running iter=130
# running iter=131
# running iter=132
# running iter=133
# running iter=134
# running iter=135
# running iter=136
# running iter=137
# running iter=138
# running iter=139
# running iter=140
# running iter=141
# running iter=142
# running iter=143
# running iter=144
# running iter=145
# running iter=146
# running iter=147
# running iter=148
# running iter=149
# running iter=150
# running iter=151
# running iter=152
# running iter=153
# running iter=154
# running iter=155
# running iter=156
# running iter=157
# running iter=158
# running iter=159
# running iter=160
# running iter=161
# running iter=162
# running iter=163
# running iter=164
# running iter=165
# running iter=166
# running iter=167
# running iter=168
# running iter=169
# running iter=170
# running iter=171
# running iter=172
# running iter=173
# running iter=174
# running iter=175
# running iter=176
# running iter=177
# running iter=178
# running iter=179
# running iter=180
# running iter=181
# running iter=182
# running iter=183
# running iter=184
# running iter=185
# running iter=186
# running iter=187
# running iter=188
# running iter=189
# running iter=190
# running iter=191
# running iter=192
# running iter=193
# running iter=194
# running iter=195
# running iter=196
# running iter=197
# running iter=198
# running iter=199
# running iter=200
# running iter=201
# running iter=202
# running iter=203
# running iter=204
# running iter=205
# running iter=206
# running iter=207
# running iter=208
# running iter=209
# running iter=210
# running iter=211
# running iter=212
# running iter=213
# running iter=214
# running iter=215
# running iter=216
# running iter=217
# running iter=218
# running iter=219
# running iter=220
# running iter=221
# running iter=222
# running iter=223
# running iter=224
# running iter=225
# running iter=226
# running iter=227
# running iter=228
# running iter=229
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 1.5520 Acc: 0.4615
# Training Epoch 5/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# running iter=67
# running iter=68
# running iter=69
# running iter=70
# running iter=71
# running iter=72
# running iter=73
# running iter=74
# running iter=75
# running iter=76
# running iter=77
# running iter=78
# running iter=79
# running iter=80
# running iter=81
# running iter=82
# running iter=83
# running iter=84
# running iter=85
# running iter=86
# running iter=87
# running iter=88
# running iter=89
# running iter=90
# running iter=91
# running iter=92
# running iter=93
# running iter=94
# running iter=95
# running iter=96
# running iter=97
# running iter=98
# running iter=99
# running iter=100
# running iter=101
# running iter=102
# running iter=103
# running iter=104
# running iter=105
# running iter=106
# running iter=107
# running iter=108
# running iter=109
# running iter=110
# running iter=111
# running iter=112
# running iter=113
# running iter=114
# running iter=115
# running iter=116
# running iter=117
# running iter=118
# running iter=119
# running iter=120
# running iter=121
# running iter=122
# running iter=123
# running iter=124
# running iter=125
# running iter=126
# running iter=127
# running iter=128
# running iter=129
# running iter=130
# running iter=131
# running iter=132
# running iter=133
# running iter=134
# running iter=135
# running iter=136
# running iter=137
# running iter=138
# running iter=139
# running iter=140
# running iter=141
# running iter=142
# running iter=143
# running iter=144
# running iter=145
# running iter=146
# running iter=147
# running iter=148
# running iter=149
# running iter=150
# running iter=151
# running iter=152
# running iter=153
# running iter=154
# running iter=155
# running iter=156
# running iter=157
# running iter=158
# running iter=159
# running iter=160
# running iter=161
# running iter=162
# running iter=163
# running iter=164
# running iter=165
# running iter=166
# running iter=167
# running iter=168
# running iter=169
# running iter=170
# running iter=171
# running iter=172
# running iter=173
# running iter=174
# running iter=175
# running iter=176
# running iter=177
# running iter=178
# running iter=179
# running iter=180
# running iter=181
# running iter=182
# running iter=183
# running iter=184
# running iter=185
# running iter=186
# running iter=187
# running iter=188
# running iter=189
# running iter=190
# running iter=191
# running iter=192
# running iter=193
# running iter=194
# running iter=195
# running iter=196
# running iter=197
# running iter=198
# running iter=199
# running iter=200
# running iter=201
# running iter=202
# running iter=203
# running iter=204
# running iter=205
# running iter=206
# running iter=207
# running iter=208
# running iter=209
# running iter=210
# running iter=211
# running iter=212
# running iter=213
# running iter=214
# running iter=215
# running iter=216
# running iter=217
# running iter=218
# running iter=219
# running iter=220
# running iter=221
# running iter=222
# running iter=223
# running iter=224
# running iter=225
# running iter=226
# running iter=227
# running iter=228
# running iter=229
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 1.5424 Acc: 0.4653
# Training Epoch 6/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# ...
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 1.5075 Acc: 0.4789
# Training Epoch 9/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# running iter=67
# running iter=68
# running iter=69
# running iter=70
# running iter=71
# running iter=72
# running iter=73
# running iter=74
# running iter=75
# running iter=76
# running iter=77
# running iter=78
# running iter=79
# running iter=80
# running iter=81
# running iter=82
# running iter=83
# running iter=84
# running iter=85
# running iter=86
# running iter=87
# running iter=88
# running iter=89
# running iter=90
# running iter=91
# running iter=92
# running iter=93
# running iter=94
# running iter=95
# running iter=96
# running iter=97
# running iter=98
# running iter=99
# running iter=100
# running iter=101
# running iter=102
# running iter=103
# running iter=104
# running iter=105
# running iter=106
# running iter=107
# running iter=108
# running iter=109
# running iter=110
# running iter=111
# running iter=112
# running iter=113
# running iter=114
# running iter=115
# running iter=116
# running iter=117
# running iter=118
# running iter=119
# running iter=120
# running iter=121
# running iter=122
# running iter=123
# running iter=124
# running iter=125
# running iter=126
# running iter=127
# running iter=128
# running iter=129
# running iter=130
# running iter=131
# running iter=132
# running iter=133
# running iter=134
# running iter=135
# running iter=136
# running iter=137
# running iter=138
# running iter=139
# running iter=140
# running iter=141
# running iter=142
# running iter=143
# running iter=144
# running iter=145
# running iter=146
# running iter=147
# running iter=148
# running iter=149
# running iter=150
# running iter=151
# running iter=152
# running iter=153
# running iter=154
# running iter=155
# running iter=156
# running iter=157
# running iter=158
# running iter=159
# running iter=160
# running iter=161
# running iter=162
# running iter=163
# running iter=164
# running iter=165
# running iter=166
# running iter=167
# running iter=168
# running iter=169
# running iter=170
# running iter=171
# running iter=172
# running iter=173
# running iter=174
# running iter=175
# running iter=176
# running iter=177
# running iter=178
# running iter=179
# running iter=180
# running iter=181
# running iter=182
# running iter=183
# running iter=184
# running iter=185
# running iter=186
# running iter=187
# running iter=188
# running iter=189
# running iter=190
# running iter=191
# running iter=192
# running iter=193
# running iter=194
# running iter=195
# running iter=196
# running iter=197
# running iter=198
# running iter=199
# running iter=200
# running iter=201
# running iter=202
# running iter=203
# running iter=204
# running iter=205
# running iter=206
# running iter=207
# running iter=208
# running iter=209
# running iter=210
# running iter=211
# running iter=212
# running iter=213
# running iter=214
# running iter=215
# running iter=216
# running iter=217
# running iter=218
# running iter=219
# running iter=220
# running iter=221
# running iter=222
# running iter=223
# running iter=224
# running iter=225
# running iter=226
# running iter=227
# running iter=228
# running iter=229
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 1.5065 Acc: 0.4791
# Training complete in 21m 12s
# running iter=0
# Val Loss: 0.0029 Acc: 0.0010
# running iter=1
# Val Loss: 0.0067 Acc: 0.0017
# running iter=2
# Val Loss: 0.0097 Acc: 0.0028
# running iter=3
# Val Loss: 0.0127 Acc: 0.0037
# running iter=4
# Val Loss: 0.0156 Acc: 0.0046
# running iter=5
# Val Loss: 0.0182 Acc: 0.0058
# running iter=6
# Val Loss: 0.0215 Acc: 0.0066
# running iter=7
# Val Loss: 0.0248 Acc: 0.0073
# running iter=8
# Val Loss: 0.0278 Acc: 0.0084
# running iter=9
# Val Loss: 0.0308 Acc: 0.0092
# running iter=10
# Val Loss: 0.0339 Acc: 0.0105
# running iter=11
# Val Loss: 0.0372 Acc: 0.0112
# running iter=12
# Val Loss: 0.0407 Acc: 0.0119
# running iter=13
# Val Loss: 0.0435 Acc: 0.0130
# running iter=14
# Val Loss: 0.0463 Acc: 0.0140
# running iter=15
# Val Loss: 0.0494 Acc: 0.0150
# running iter=16
# Val Loss: 0.0526 Acc: 0.0160
# running iter=17
# Val Loss: 0.0556 Acc: 0.0170
# running iter=18
# Val Loss: 0.0585 Acc: 0.0180
# running iter=19
# Val Loss: 0.0615 Acc: 0.0189
# running iter=20
# Val Loss: 0.0647 Acc: 0.0198
# running iter=21
# Val Loss: 0.0678 Acc: 0.0208
# running iter=22
# Val Loss: 0.0711 Acc: 0.0217
# running iter=23
# Val Loss: 0.0742 Acc: 0.0226
# running iter=24
# Val Loss: 0.0777 Acc: 0.0235
# running iter=25
# Val Loss: 0.0809 Acc: 0.0243
# running iter=26
# Val Loss: 0.0836 Acc: 0.0253
# running iter=27
# Val Loss: 0.0864 Acc: 0.0262
# running iter=28
# Val Loss: 0.0894 Acc: 0.0274
# running iter=29
# Val Loss: 0.0926 Acc: 0.0283
# running iter=30
# Val Loss: 0.0954 Acc: 0.0292
# running iter=31
# Val Loss: 0.0983 Acc: 0.0303
# running iter=32
# Val Loss: 0.1015 Acc: 0.0312
# running iter=33
# Val Loss: 0.1046 Acc: 0.0321
# running iter=34
# Val Loss: 0.1077 Acc: 0.0330
# running iter=35
# Val Loss: 0.1105 Acc: 0.0339
# running iter=36
# Val Loss: 0.1141 Acc: 0.0346
# running iter=37
# Val Loss: 0.1173 Acc: 0.0356
# running iter=38
# Val Loss: 0.1200 Acc: 0.0366
# running iter=39
# Val Loss: 0.1231 Acc: 0.0375
# running iter=40
# Val Loss: 0.1260 Acc: 0.0386
# running iter=41
# Val Loss: 0.1292 Acc: 0.0396
# running iter=42
# Val Loss: 0.1321 Acc: 0.0407
# running iter=43
# Val Loss: 0.1354 Acc: 0.0415
# running iter=44
# Val Loss: 0.1385 Acc: 0.0425
# running iter=45
# Val Loss: 0.1415 Acc: 0.0435
# running iter=46
# Val Loss: 0.1446 Acc: 0.0444
# running iter=47
# Val Loss: 0.1481 Acc: 0.0452
# running iter=48
# Val Loss: 0.1514 Acc: 0.0461
# running iter=49
# Val Loss: 0.1546 Acc: 0.0470
# running iter=50
# Val Loss: 0.1576 Acc: 0.0479
# running iter=51
# Val Loss: 0.1610 Acc: 0.0488
# running iter=52
# Val Loss: 0.1642 Acc: 0.0496
# running iter=53
# Val Loss: 0.1676 Acc: 0.0505
# running iter=54
# Val Loss: 0.1708 Acc: 0.0514
# running iter=55
# Val Loss: 0.1738 Acc: 0.0525
# running iter=56
# Val Loss: 0.1775 Acc: 0.0532
# running iter=57
# Val Loss: 0.1802 Acc: 0.0543
# running iter=58
# Val Loss: 0.1834 Acc: 0.0552
# running iter=59
# Val Loss: 0.1867 Acc: 0.0561
# running iter=60
# Val Loss: 0.1898 Acc: 0.0570
# running iter=61
# Val Loss: 0.1933 Acc: 0.0578
# running iter=62
# Val Loss: 0.1962 Acc: 0.0588
# running iter=63
# Val Loss: 0.1992 Acc: 0.0597
# running iter=64
# Val Loss: 0.2024 Acc: 0.0606
# running iter=65
# Val Loss: 0.2058 Acc: 0.0616
# running iter=66
# Val Loss: 0.2088 Acc: 0.0627
# running iter=67
# Val Loss: 0.2120 Acc: 0.0637
# running iter=68
# Val Loss: 0.2148 Acc: 0.0647
# running iter=69
# Val Loss: 0.2182 Acc: 0.0656
# running iter=70
# Val Loss: 0.2211 Acc: 0.0665
# running iter=71
# Val Loss: 0.2244 Acc: 0.0674
# running iter=72
# Val Loss: 0.2277 Acc: 0.0683
# running iter=73
# Val Loss: 0.2306 Acc: 0.0694
# running iter=74
# Val Loss: 0.2337 Acc: 0.0704
# running iter=75
# Val Loss: 0.2366 Acc: 0.0713
# running iter=76
# Val Loss: 0.2395 Acc: 0.0723
# running iter=77
# Val Loss: 0.2428 Acc: 0.0733
# running iter=78
# Val Loss: 0.2459 Acc: 0.0744
# running iter=79
# Val Loss: 0.2493 Acc: 0.0752
# running iter=80
# Val Loss: 0.2526 Acc: 0.0761
# running iter=81
# Val Loss: 0.2557 Acc: 0.0770
# running iter=82
# Val Loss: 0.2590 Acc: 0.0778
# running iter=83
# Val Loss: 0.2623 Acc: 0.0787
# running iter=84
# Val Loss: 0.2658 Acc: 0.0795
# running iter=85
# Val Loss: 0.2691 Acc: 0.0803
# running iter=86
# Val Loss: 0.2725 Acc: 0.0811
# running iter=87
# Val Loss: 0.2757 Acc: 0.0820
# running iter=88
# Val Loss: 0.2791 Acc: 0.0828
# running iter=89
# Val Loss: 0.2822 Acc: 0.0838
# running iter=90
# Val Loss: 0.2855 Acc: 0.0848
# running iter=91
# Val Loss: 0.2884 Acc: 0.0858
# running iter=92
# Val Loss: 0.2913 Acc: 0.0868
# running iter=93
# Val Loss: 0.2948 Acc: 0.0876
# running iter=94
# Val Loss: 0.2979 Acc: 0.0885
# running iter=95
# Val Loss: 0.3010 Acc: 0.0894
# running iter=96
# Val Loss: 0.3043 Acc: 0.0902
# running iter=97
# Val Loss: 0.3078 Acc: 0.0910
# running iter=98
# Val Loss: 0.3106 Acc: 0.0921
# running iter=99
# Val Loss: 0.3134 Acc: 0.0932
# validation complete in 0m 23s

# %%
cifar_10_dir = '/content/drive/My Drive/saved_model-problemb.pkl'

with open(cifar_10_dir, 'wb') as fo:
    pickle.dump(trained_model, fo)

# %%
i = 0
total_c = 10000

inputs = test_data[i*total_c:(i+1)*total_c:,:]
labels = test_labels[i*total_c:(i+1)*total_c]

inputs = torch.from_numpy(inputs)
labels = torch.from_numpy(labels)

inputs = inputs.type(torch.FloatTensor)

with torch.no_grad():
    outputs = trained_model(inputs)
    _, preds = torch.max(outputs, 1)

prob = torch.nn.functional.softmax(outputs, dim=1)
top_p, top_class = prob.topk(1, dim = 1)
top_p = top_p.numpy()

x = heapq.nlargest(5, range(len(top_p)), top_p.take)
y = heapq.nsmallest(5, range(len(top_p)), top_p.take)

for m in range(len(x)):
  print("Confidence = " + str(top_p[x[m]]) + " good - predicted = " + str(label_names[preds[x[m]]]) + " actual = " + str(label_names[test_labels[x[m]]]))

for m in range(len(y)):
  print("Confidence = " + str(top_p[y[m]]) + " bad - predicted = " + str(label_names[preds[y[m]]]) + " actual = " + str(label_names[test_labels[y[m]]]))
# Out:
# Confidence = [0.99983513] good - predicted = b'dog' actual = b'dog'
# Confidence = [0.9996226] good - predicted = b'automobile' actual = b'automobile'
# Confidence = [0.9993326] good - predicted = b'dog' actual = b'dog'
# Confidence = [0.998684] good - predicted = b'frog' actual = b'frog'
# Confidence = [0.9981623] good - predicted = b'horse' actual = b'horse'
# Confidence = [0.13016853] bad - predicted = b'automobile' actual = b'ship'
# Confidence = [0.1315625] bad - predicted = b'ship' actual = b'truck'
# Confidence = [0.13398966] bad - predicted = b'frog' actual = b'cat'
# Confidence = [0.13644743] bad - predicted = b'dog' actual = b'dog'
# Confidence = [0.13765663] bad - predicted = b'cat' actual = b'cat'

# %% [markdown]
# **PART C:** Finetune the Resnet18 model's parameters suitably and repeat parts (a) and (b) from above. Compare the performance of finetuning versus using extracted features.

# %%
import pickle
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from google.colab import drive
import heapq

drive.mount('/content/drive')
# %cd /content/drive/My Drive/movielens
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive

# %%
# this code was reused from https://github.com/snatch59/load-cifar-10 as coded by Petras Saduikis
def unpickle(file):
    """load the cifar-10 data"""

    with open(file, 'rb') as fo:
        data = pickle.load(fo, encoding='bytes')
    return data


def load_cifar_10_data(data_dir, negatives=False):
    """
    Return train_data, train_filenames, train_labels, test_data, test_filenames, test_labels
    """

    # get the meta_data_dict
    # num_cases_per_batch: 1000
    # label_names: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
    # num_vis: :3072

    meta_data_dict = unpickle(data_dir + "/batches.meta")
    cifar_label_names = meta_data_dict[b'label_names']
    cifar_label_names = np.array(cifar_label_names)

    # training data
    cifar_train_data = None
    cifar_train_filenames = []
    cifar_train_labels = []

    # cifar_train_data_dict
    # 'batch_label': 'training batch 5 of 5'
    # 'data': ndarray
    # 'filenames': list
    # 'labels': list

    for i in range(1, 6):
        cifar_train_data_dict = unpickle(data_dir + "/data_batch_{}".format(i))
        if i == 1:
            cifar_train_data = cifar_train_data_dict[b'data']
        else:
            cifar_train_data = np.vstack((cifar_train_data, cifar_train_data_dict[b'data']))
        cifar_train_filenames += cifar_train_data_dict[b'filenames']
        cifar_train_labels += cifar_train_data_dict[b'labels']

    cifar_train_data = cifar_train_data.reshape((len(cifar_train_data), 3, 32, 32))
    if negatives:
        cifar_train_data = cifar_train_data.transpose(0, 2, 3, 1).astype(np.float32)
    #else:
        #cifar_train_data = np.rollaxis(cifar_train_data, 1, 4)
    cifar_train_filenames = np.array(cifar_train_filenames)
    cifar_train_labels = np.array(cifar_train_labels)

    # test data
    # cifar_test_data_dict
    # 'batch_label': 'testing batch 1 of 1'
    # 'data': ndarray
    # 'filenames': list
    # 'labels': list

    cifar_test_data_dict = unpickle(data_dir + "/test_batch")
    cifar_test_data = cifar_test_data_dict[b'data']
    cifar_test_filenames = cifar_test_data_dict[b'filenames']
    cifar_test_labels = cifar_test_data_dict[b'labels']

    cifar_test_data = cifar_test_data.reshape((len(cifar_test_data), 3, 32, 32))
    if negatives:
        cifar_test_data = cifar_test_data.transpose(0, 2, 3, 1).astype(np.float32)
    #else:
        #cifar_test_data = np.rollaxis(cifar_test_data, 1, 4)
    cifar_test_filenames = np.array(cifar_test_filenames)
    cifar_test_labels = np.array(cifar_test_labels)

    return cifar_train_data, cifar_train_filenames, cifar_train_labels, \
        cifar_test_data, cifar_test_filenames, cifar_test_labels, cifar_label_names

# %%
cifar_10_dir = '/content/drive/My Drive/cifar-10-batches-py'

train_data, train_filenames, train_labels, test_data, test_filenames, test_labels, label_names = \
    load_cifar_10_data(cifar_10_dir)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    dataset_size = train_data.shape[0]

    for epoch in range(num_epochs):
        print('Training Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # training phase
        phase = 'train'
        model.train()  # Set model to training mode
        running_loss = 0.0
        running_corrects = 0

        # Iterate over data. must be from 0 to 500
        for i in range(0, 500):
            print ('running iter='+str(i))
            inputs = train_data[i*100:(i+1)*100:,:]
            labels = train_labels[i*100:(i+1)*100]

            # zero the parameter gradients
            optimizer.zero_grad()

            inputs = torch.from_numpy(inputs)
            labels = torch.from_numpy(labels)

            inputs = inputs.type(torch.FloatTensor)

            # forward
            # track history if only in train
            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                #perform backword and optimize in training
                loss.backward()
                optimizer.step()

            # statistics
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        scheduler.step()   
        epoch_loss = running_loss / dataset_size
        epoch_acc = running_corrects.double() / dataset_size

        print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))             
  
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    return model

##################################################################################

def validate_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    dataset_size = train_data.shape[0]

    # validation phase
    phase = 'Val'
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    # Iterate over data. must be from 0 to 99
    for i in range(0,100):
        print ('running iter='+str(i))
        inputs = test_data[i*100:(i+1)*100:,:]
        labels = test_labels[i*100:(i+1)*100]

        # zero the parameter gradients
        optimizer.zero_grad()

        inputs = torch.from_numpy(inputs)
        labels = torch.from_numpy(labels)

        inputs = inputs.type(torch.FloatTensor)

        # forward
        # track history if only in train
        with torch.set_grad_enabled(phase == 'train'):
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        # statistics
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / dataset_size
        epoch_acc = running_corrects.double() / dataset_size

        print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))             
  
    time_elapsed = time.time() - since
    print('validation complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    return epoch_loss, epoch_acc
#####################################################################################

model_ft = torchvision.models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
nn.Linear(num_ftrs, 10)
model_ft.fc = nn.Linear(num_ftrs, 10)
model_ft = model_ft.to(device)
criterion = nn.CrossEntropyLoss()
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

trained_model = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,num_epochs=10)
a, b = validate_model(trained_model, criterion, optimizer_ft, exp_lr_scheduler,num_epochs=2)
print("Loss = ", a)
print("Accuracy = ", b)
# Out:
# Streaming output truncated to the last 5000 lines.
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 1.1146 Acc: 0.6106
# Training Epoch 1/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# running iter=67
# running iter=68
# running iter=69
# running iter=70
# running iter=71
# running iter=72
# running iter=73
# running iter=74
# running iter=75
# running iter=76
# running iter=77
# running iter=78
# running iter=79
# running iter=80
# running iter=81
# running iter=82
# running iter=83
# running iter=84
# running iter=85
# running iter=86
# running iter=87
# running iter=88
# running iter=89
# running iter=90
# running iter=91
# running iter=92
# running iter=93
# running iter=94
# running iter=95
# running iter=96
# running iter=97
# running iter=98
# running iter=99
# running iter=100
# running iter=101
# running iter=102
# running iter=103
# running iter=104
# running iter=105
# running iter=106
# running iter=107
# running iter=108
# running iter=109
# running iter=110
# running iter=111
# running iter=112
# running iter=113
# running iter=114
# running iter=115
# running iter=116
# running iter=117
# running iter=118
# running iter=119
# running iter=120
# running iter=121
# running iter=122
# running iter=123
# running iter=124
# running iter=125
# running iter=126
# running iter=127
# running iter=128
# running iter=129
# running iter=130
# running iter=131
# running iter=132
# running iter=133
# running iter=134
# running iter=135
# running iter=136
# running iter=137
# running iter=138
# running iter=139
# running iter=140
# running iter=141
# running iter=142
# running iter=143
# running iter=144
# running iter=145
# running iter=146
# running iter=147
# running iter=148
# running iter=149
# running iter=150
# running iter=151
# running iter=152
# running iter=153
# running iter=154
# running iter=155
# running iter=156
# running iter=157
# running iter=158
# running iter=159
# running iter=160
# running iter=161
# running iter=162
# running iter=163
# running iter=164
# running iter=165
# running iter=166
# running iter=167
# running iter=168
# running iter=169
# running iter=170
# running iter=171
# running iter=172
# running iter=173
# running iter=174
# running iter=175
# running iter=176
# running iter=177
# running iter=178
# running iter=179
# running iter=180
# running iter=181
# running iter=182
# running iter=183
# running iter=184
# running iter=185
# running iter=186
# running iter=187
# running iter=188
# running iter=189
# running iter=190
# running iter=191
# running iter=192
# running iter=193
# running iter=194
# running iter=195
# running iter=196
# running iter=197
# running iter=198
# running iter=199
# running iter=200
# running iter=201
# running iter=202
# running iter=203
# running iter=204
# running iter=205
# running iter=206
# running iter=207
# running iter=208
# running iter=209
# running iter=210
# running iter=211
# running iter=212
# running iter=213
# running iter=214
# running iter=215
# running iter=216
# running iter=217
# running iter=218
# running iter=219
# running iter=220
# running iter=221
# running iter=222
# running iter=223
# running iter=224
# running iter=225
# running iter=226
# running iter=227
# running iter=228
# running iter=229
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 0.6265 Acc: 0.7833
# Training Epoch 2/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# running iter=67
# running iter=68
# running iter=69
# running iter=70
# running iter=71
# running iter=72
# running iter=73
# running iter=74
# running iter=75
# running iter=76
# running iter=77
# running iter=78
# running iter=79
# running iter=80
# running iter=81
# running iter=82
# running iter=83
# running iter=84
# running iter=85
# running iter=86
# running iter=87
# running iter=88
# running iter=89
# running iter=90
# running iter=91
# running iter=92
# running iter=93
# running iter=94
# running iter=95
# running iter=96
# running iter=97
# running iter=98
# running iter=99
# running iter=100
# running iter=101
# running iter=102
# running iter=103
# running iter=104
# running iter=105
# running iter=106
# running iter=107
# running iter=108
# running iter=109
# running iter=110
# running iter=111
# running iter=112
# running iter=113
# running iter=114
# running iter=115
# running iter=116
# running iter=117
# running iter=118
# running iter=119
# running iter=120
# running iter=121
# running iter=122
# running iter=123
# running iter=124
# running iter=125
# running iter=126
# running iter=127
# running iter=128
# running iter=129
# running iter=130
# running iter=131
# running iter=132
# running iter=133
# running iter=134
# running iter=135
# running iter=136
# running iter=137
# running iter=138
# running iter=139
# running iter=140
# running iter=141
# running iter=142
# running iter=143
# running iter=144
# running iter=145
# running iter=146
# running iter=147
# running iter=148
# running iter=149
# running iter=150
# running iter=151
# running iter=152
# running iter=153
# running iter=154
# running iter=155
# running iter=156
# running iter=157
# running iter=158
# running iter=159
# running iter=160
# running iter=161
# running iter=162
# running iter=163
# running iter=164
# running iter=165
# running iter=166
# running iter=167
# running iter=168
# running iter=169
# running iter=170
# running iter=171
# running iter=172
# running iter=173
# running iter=174
# running iter=175
# running iter=176
# running iter=177
# running iter=178
# running iter=179
# running iter=180
# running iter=181
# running iter=182
# running iter=183
# running iter=184
# running iter=185
# running iter=186
# running iter=187
# running iter=188
# running iter=189
# running iter=190
# running iter=191
# running iter=192
# running iter=193
# running iter=194
# running iter=195
# running iter=196
# running iter=197
# running iter=198
# running iter=199
# running iter=200
# running iter=201
# running iter=202
# running iter=203
# running iter=204
# running iter=205
# running iter=206
# running iter=207
# running iter=208
# running iter=209
# running iter=210
# running iter=211
# running iter=212
# running iter=213
# running iter=214
# running iter=215
# running iter=216
# running iter=217
# running iter=218
# running iter=219
# running iter=220
# running iter=221
# running iter=222
# running iter=223
# running iter=224
# running iter=225
# running iter=226
# running iter=227
# running iter=228
# running iter=229
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 0.3966 Acc: 0.8699
# Training Epoch 3/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# running iter=67
# running iter=68
# running iter=69
# running iter=70
# running iter=71
# running iter=72
# running iter=73
# running iter=74
# running iter=75
# running iter=76
# running iter=77
# running iter=78
# running iter=79
# running iter=80
# running iter=81
# running iter=82
# running iter=83
# running iter=84
# running iter=85
# running iter=86
# running iter=87
# running iter=88
# running iter=89
# running iter=90
# running iter=91
# running iter=92
# running iter=93
# running iter=94
# running iter=95
# running iter=96
# running iter=97
# running iter=98
# running iter=99
# running iter=100
# running iter=101
# running iter=102
# running iter=103
# running iter=104
# running iter=105
# running iter=106
# running iter=107
# running iter=108
# running iter=109
# running iter=110
# running iter=111
# running iter=112
# running iter=113
# running iter=114
# running iter=115
# running iter=116
# running iter=117
# running iter=118
# running iter=119
# running iter=120
# running iter=121
# running iter=122
# running iter=123
# running iter=124
# running iter=125
# running iter=126
# running iter=127
# running iter=128
# running iter=129
# running iter=130
# running iter=131
# running iter=132
# running iter=133
# running iter=134
# running iter=135
# running iter=136
# running iter=137
# running iter=138
# running iter=139
# running iter=140
# running iter=141
# running iter=142
# running iter=143
# running iter=144
# running iter=145
# running iter=146
# running iter=147
# running iter=148
# running iter=149
# running iter=150
# running iter=151
# running iter=152
# running iter=153
# running iter=154
# running iter=155
# running iter=156
# running iter=157
# running iter=158
# running iter=159
# running iter=160
# running iter=161
# running iter=162
# running iter=163
# running iter=164
# running iter=165
# running iter=166
# running iter=167
# running iter=168
# running iter=169
# running iter=170
# running iter=171
# running iter=172
# running iter=173
# running iter=174
# running iter=175
# running iter=176
# running iter=177
# running iter=178
# running iter=179
# running iter=180
# running iter=181
# running iter=182
# running iter=183
# running iter=184
# running iter=185
# running iter=186
# running iter=187
# running iter=188
# running iter=189
# running iter=190
# running iter=191
# running iter=192
# running iter=193
# running iter=194
# running iter=195
# running iter=196
# running iter=197
# running iter=198
# running iter=199
# running iter=200
# running iter=201
# running iter=202
# running iter=203
# running iter=204
# running iter=205
# running iter=206
# running iter=207
# running iter=208
# running iter=209
# running iter=210
# running iter=211
# running iter=212
# running iter=213
# running iter=214
# running iter=215
# running iter=216
# running iter=217
# running iter=218
# running iter=219
# running iter=220
# running iter=221
# running iter=222
# running iter=223
# running iter=224
# running iter=225
# running iter=226
# running iter=227
# running iter=228
# running iter=229
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 0.2135 Acc: 0.9377
# Training Epoch 4/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# running iter=67
# running iter=68
# running iter=69
# running iter=70
# running iter=71
# running iter=72
# running iter=73
# running iter=74
# running iter=75
# running iter=76
# running iter=77
# running iter=78
# running iter=79
# running iter=80
# running iter=81
# running iter=82
# running iter=83
# running iter=84
# running iter=85
# running iter=86
# running iter=87
# running iter=88
# running iter=89
# running iter=90
# running iter=91
# running iter=92
# running iter=93
# running iter=94
# running iter=95
# running iter=96
# running iter=97
# running iter=98
# running iter=99
# running iter=100
# running iter=101
# running iter=102
# running iter=103
# running iter=104
# running iter=105
# running iter=106
# running iter=107
# running iter=108
# running iter=109
# running iter=110
# running iter=111
# running iter=112
# running iter=113
# running iter=114
# running iter=115
# running iter=116
# running iter=117
# running iter=118
# running iter=119
# running iter=120
# running iter=121
# running iter=122
# running iter=123
# running iter=124
# running iter=125
# running iter=126
# running iter=127
# running iter=128
# running iter=129
# running iter=130
# running iter=131
# running iter=132
# running iter=133
# running iter=134
# running iter=135
# running iter=136
# running iter=137
# running iter=138
# running iter=139
# running iter=140
# running iter=141
# running iter=142
# running iter=143
# running iter=144
# running iter=145
# running iter=146
# running iter=147
# running iter=148
# running iter=149
# running iter=150
# running iter=151
# running iter=152
# running iter=153
# running iter=154
# running iter=155
# running iter=156
# running iter=157
# running iter=158
# running iter=159
# running iter=160
# running iter=161
# running iter=162
# running iter=163
# running iter=164
# running iter=165
# running iter=166
# running iter=167
# running iter=168
# running iter=169
# running iter=170
# running iter=171
# running iter=172
# running iter=173
# running iter=174
# running iter=175
# running iter=176
# running iter=177
# running iter=178
# running iter=179
# running iter=180
# running iter=181
# running iter=182
# running iter=183
# running iter=184
# running iter=185
# running iter=186
# running iter=187
# running iter=188
# running iter=189
# running iter=190
# running iter=191
# running iter=192
# running iter=193
# running iter=194
# running iter=195
# running iter=196
# running iter=197
# running iter=198
# running iter=199
# running iter=200
# running iter=201
# running iter=202
# running iter=203
# running iter=204
# running iter=205
# running iter=206
# running iter=207
# running iter=208
# running iter=209
# running iter=210
# running iter=211
# running iter=212
# running iter=213
# running iter=214
# running iter=215
# running iter=216
# running iter=217
# running iter=218
# running iter=219
# running iter=220
# running iter=221
# running iter=222
# running iter=223
# running iter=224
# running iter=225
# running iter=226
# running iter=227
# running iter=228
# running iter=229
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 0.0904 Acc: 0.9801
# Training Epoch 5/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# running iter=67
# running iter=68
# running iter=69
# running iter=70
# running iter=71
# running iter=72
# running iter=73
# running iter=74
# running iter=75
# running iter=76
# running iter=77
# running iter=78
# running iter=79
# running iter=80
# running iter=81
# running iter=82
# running iter=83
# running iter=84
# running iter=85
# running iter=86
# running iter=87
# running iter=88
# running iter=89
# running iter=90
# running iter=91
# running iter=92
# running iter=93
# running iter=94
# running iter=95
# running iter=96
# running iter=97
# running iter=98
# running iter=99
# running iter=100
# running iter=101
# running iter=102
# running iter=103
# running iter=104
# running iter=105
# running iter=106
# running iter=107
# running iter=108
# running iter=109
# running iter=110
# running iter=111
# running iter=112
# running iter=113
# running iter=114
# running iter=115
# running iter=116
# running iter=117
# running iter=118
# running iter=119
# running iter=120
# running iter=121
# running iter=122
# running iter=123
# running iter=124
# running iter=125
# running iter=126
# running iter=127
# running iter=128
# running iter=129
# running iter=130
# running iter=131
# running iter=132
# running iter=133
# running iter=134
# running iter=135
# running iter=136
# running iter=137
# running iter=138
# running iter=139
# running iter=140
# running iter=141
# running iter=142
# running iter=143
# running iter=144
# running iter=145
# running iter=146
# running iter=147
# running iter=148
# running iter=149
# running iter=150
# running iter=151
# running iter=152
# running iter=153
# running iter=154
# running iter=155
# running iter=156
# running iter=157
# running iter=158
# running iter=159
# running iter=160
# running iter=161
# running iter=162
# running iter=163
# running iter=164
# running iter=165
# running iter=166
# running iter=167
# running iter=168
# running iter=169
# running iter=170
# running iter=171
# running iter=172
# running iter=173
# running iter=174
# running iter=175
# running iter=176
# running iter=177
# running iter=178
# running iter=179
# running iter=180
# running iter=181
# running iter=182
# running iter=183
# running iter=184
# running iter=185
# running iter=186
# running iter=187
# running iter=188
# running iter=189
# running iter=190
# running iter=191
# running iter=192
# running iter=193
# running iter=194
# running iter=195
# running iter=196
# running iter=197
# running iter=198
# running iter=199
# running iter=200
# running iter=201
# running iter=202
# running iter=203
# running iter=204
# running iter=205
# running iter=206
# running iter=207
# running iter=208
# running iter=209
# running iter=210
# running iter=211
# running iter=212
# running iter=213
# running iter=214
# running iter=215
# running iter=216
# running iter=217
# running iter=218
# running iter=219
# running iter=220
# running iter=221
# running iter=222
# running iter=223
# running iter=224
# running iter=225
# running iter=226
# running iter=227
# running iter=228
# running iter=229
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 0.0362 Acc: 0.9945
# Training Epoch 6/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# ...
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 0.0073 Acc: 0.9999
# Training Epoch 9/9
# ----------
# running iter=0
# running iter=1
# running iter=2
# running iter=3
# running iter=4
# running iter=5
# running iter=6
# running iter=7
# running iter=8
# running iter=9
# running iter=10
# running iter=11
# running iter=12
# running iter=13
# running iter=14
# running iter=15
# running iter=16
# running iter=17
# running iter=18
# running iter=19
# running iter=20
# running iter=21
# running iter=22
# running iter=23
# running iter=24
# running iter=25
# running iter=26
# running iter=27
# running iter=28
# running iter=29
# running iter=30
# running iter=31
# running iter=32
# running iter=33
# running iter=34
# running iter=35
# running iter=36
# running iter=37
# running iter=38
# running iter=39
# running iter=40
# running iter=41
# running iter=42
# running iter=43
# running iter=44
# running iter=45
# running iter=46
# running iter=47
# running iter=48
# running iter=49
# running iter=50
# running iter=51
# running iter=52
# running iter=53
# running iter=54
# running iter=55
# running iter=56
# running iter=57
# running iter=58
# running iter=59
# running iter=60
# running iter=61
# running iter=62
# running iter=63
# running iter=64
# running iter=65
# running iter=66
# running iter=67
# running iter=68
# running iter=69
# running iter=70
# running iter=71
# running iter=72
# running iter=73
# running iter=74
# running iter=75
# running iter=76
# running iter=77
# running iter=78
# running iter=79
# running iter=80
# running iter=81
# running iter=82
# running iter=83
# running iter=84
# running iter=85
# running iter=86
# running iter=87
# running iter=88
# running iter=89
# running iter=90
# running iter=91
# running iter=92
# running iter=93
# running iter=94
# running iter=95
# running iter=96
# running iter=97
# running iter=98
# running iter=99
# running iter=100
# running iter=101
# running iter=102
# running iter=103
# running iter=104
# running iter=105
# running iter=106
# running iter=107
# running iter=108
# running iter=109
# running iter=110
# running iter=111
# running iter=112
# running iter=113
# running iter=114
# running iter=115
# running iter=116
# running iter=117
# running iter=118
# running iter=119
# running iter=120
# running iter=121
# running iter=122
# running iter=123
# running iter=124
# running iter=125
# running iter=126
# running iter=127
# running iter=128
# running iter=129
# running iter=130
# running iter=131
# running iter=132
# running iter=133
# running iter=134
# running iter=135
# running iter=136
# running iter=137
# running iter=138
# running iter=139
# running iter=140
# running iter=141
# running iter=142
# running iter=143
# running iter=144
# running iter=145
# running iter=146
# running iter=147
# running iter=148
# running iter=149
# running iter=150
# running iter=151
# running iter=152
# running iter=153
# running iter=154
# running iter=155
# running iter=156
# running iter=157
# running iter=158
# running iter=159
# running iter=160
# running iter=161
# running iter=162
# running iter=163
# running iter=164
# running iter=165
# running iter=166
# running iter=167
# running iter=168
# running iter=169
# running iter=170
# running iter=171
# running iter=172
# running iter=173
# running iter=174
# running iter=175
# running iter=176
# running iter=177
# running iter=178
# running iter=179
# running iter=180
# running iter=181
# running iter=182
# running iter=183
# running iter=184
# running iter=185
# running iter=186
# running iter=187
# running iter=188
# running iter=189
# running iter=190
# running iter=191
# running iter=192
# running iter=193
# running iter=194
# running iter=195
# running iter=196
# running iter=197
# running iter=198
# running iter=199
# running iter=200
# running iter=201
# running iter=202
# running iter=203
# running iter=204
# running iter=205
# running iter=206
# running iter=207
# running iter=208
# running iter=209
# running iter=210
# running iter=211
# running iter=212
# running iter=213
# running iter=214
# running iter=215
# running iter=216
# running iter=217
# running iter=218
# running iter=219
# running iter=220
# running iter=221
# running iter=222
# running iter=223
# running iter=224
# running iter=225
# running iter=226
# running iter=227
# running iter=228
# running iter=229
# running iter=230
# running iter=231
# running iter=232
# running iter=233
# running iter=234
# running iter=235
# running iter=236
# running iter=237
# running iter=238
# running iter=239
# running iter=240
# running iter=241
# running iter=242
# running iter=243
# running iter=244
# running iter=245
# running iter=246
# running iter=247
# running iter=248
# running iter=249
# running iter=250
# running iter=251
# running iter=252
# running iter=253
# running iter=254
# running iter=255
# running iter=256
# running iter=257
# running iter=258
# running iter=259
# running iter=260
# running iter=261
# running iter=262
# running iter=263
# running iter=264
# running iter=265
# running iter=266
# running iter=267
# running iter=268
# running iter=269
# running iter=270
# running iter=271
# running iter=272
# running iter=273
# running iter=274
# running iter=275
# running iter=276
# running iter=277
# running iter=278
# running iter=279
# running iter=280
# running iter=281
# running iter=282
# running iter=283
# running iter=284
# running iter=285
# running iter=286
# running iter=287
# running iter=288
# running iter=289
# running iter=290
# running iter=291
# running iter=292
# running iter=293
# running iter=294
# running iter=295
# running iter=296
# running iter=297
# running iter=298
# running iter=299
# running iter=300
# running iter=301
# running iter=302
# running iter=303
# running iter=304
# running iter=305
# running iter=306
# running iter=307
# running iter=308
# running iter=309
# running iter=310
# running iter=311
# running iter=312
# running iter=313
# running iter=314
# running iter=315
# running iter=316
# running iter=317
# running iter=318
# running iter=319
# running iter=320
# running iter=321
# running iter=322
# running iter=323
# running iter=324
# running iter=325
# running iter=326
# running iter=327
# running iter=328
# running iter=329
# running iter=330
# running iter=331
# running iter=332
# running iter=333
# running iter=334
# running iter=335
# running iter=336
# running iter=337
# running iter=338
# running iter=339
# running iter=340
# running iter=341
# running iter=342
# running iter=343
# running iter=344
# running iter=345
# running iter=346
# running iter=347
# running iter=348
# running iter=349
# running iter=350
# running iter=351
# running iter=352
# running iter=353
# running iter=354
# running iter=355
# running iter=356
# running iter=357
# running iter=358
# running iter=359
# running iter=360
# running iter=361
# running iter=362
# running iter=363
# running iter=364
# running iter=365
# running iter=366
# running iter=367
# running iter=368
# running iter=369
# running iter=370
# running iter=371
# running iter=372
# running iter=373
# running iter=374
# running iter=375
# running iter=376
# running iter=377
# running iter=378
# running iter=379
# running iter=380
# running iter=381
# running iter=382
# running iter=383
# running iter=384
# running iter=385
# running iter=386
# running iter=387
# running iter=388
# running iter=389
# running iter=390
# running iter=391
# running iter=392
# running iter=393
# running iter=394
# running iter=395
# running iter=396
# running iter=397
# running iter=398
# running iter=399
# running iter=400
# running iter=401
# running iter=402
# running iter=403
# running iter=404
# running iter=405
# running iter=406
# running iter=407
# running iter=408
# running iter=409
# running iter=410
# running iter=411
# running iter=412
# running iter=413
# running iter=414
# running iter=415
# running iter=416
# running iter=417
# running iter=418
# running iter=419
# running iter=420
# running iter=421
# running iter=422
# running iter=423
# running iter=424
# running iter=425
# running iter=426
# running iter=427
# running iter=428
# running iter=429
# running iter=430
# running iter=431
# running iter=432
# running iter=433
# running iter=434
# running iter=435
# running iter=436
# running iter=437
# running iter=438
# running iter=439
# running iter=440
# running iter=441
# running iter=442
# running iter=443
# running iter=444
# running iter=445
# running iter=446
# running iter=447
# running iter=448
# running iter=449
# running iter=450
# running iter=451
# running iter=452
# running iter=453
# running iter=454
# running iter=455
# running iter=456
# running iter=457
# running iter=458
# running iter=459
# running iter=460
# running iter=461
# running iter=462
# running iter=463
# running iter=464
# running iter=465
# running iter=466
# running iter=467
# running iter=468
# running iter=469
# running iter=470
# running iter=471
# running iter=472
# running iter=473
# running iter=474
# running iter=475
# running iter=476
# running iter=477
# running iter=478
# running iter=479
# running iter=480
# running iter=481
# running iter=482
# running iter=483
# running iter=484
# running iter=485
# running iter=486
# running iter=487
# running iter=488
# running iter=489
# running iter=490
# running iter=491
# running iter=492
# running iter=493
# running iter=494
# running iter=495
# running iter=496
# running iter=497
# running iter=498
# running iter=499
# train Loss: 0.0063 Acc: 1.0000
# Training complete in 80m 11s
# running iter=0
# Val Loss: 0.0022 Acc: 0.0016
# running iter=1
# Val Loss: 0.0051 Acc: 0.0031
# running iter=2
# Val Loss: 0.0070 Acc: 0.0046
# running iter=3
# Val Loss: 0.0100 Acc: 0.0061
# running iter=4
# Val Loss: 0.0120 Acc: 0.0076
# running iter=5
# Val Loss: 0.0136 Acc: 0.0093
# running iter=6
# Val Loss: 0.0158 Acc: 0.0108
# running iter=7
# Val Loss: 0.0182 Acc: 0.0123
# running iter=8
# Val Loss: 0.0209 Acc: 0.0138
# running iter=9
# Val Loss: 0.0226 Acc: 0.0154
# running iter=10
# Val Loss: 0.0248 Acc: 0.0170
# running iter=11
# Val Loss: 0.0269 Acc: 0.0185
# running iter=12
# Val Loss: 0.0301 Acc: 0.0200
# running iter=13
# Val Loss: 0.0316 Acc: 0.0216
# running iter=14
# Val Loss: 0.0334 Acc: 0.0232
# running iter=15
# Val Loss: 0.0363 Acc: 0.0246
# running iter=16
# Val Loss: 0.0380 Acc: 0.0263
# running iter=17
# Val Loss: 0.0404 Acc: 0.0279
# running iter=18
# Val Loss: 0.0428 Acc: 0.0293
# running iter=19
# Val Loss: 0.0458 Acc: 0.0307
# running iter=20
# Val Loss: 0.0489 Acc: 0.0321
# running iter=21
# Val Loss: 0.0515 Acc: 0.0335
# running iter=22
# Val Loss: 0.0539 Acc: 0.0350
# running iter=23
# Val Loss: 0.0558 Acc: 0.0366
# running iter=24
# Val Loss: 0.0587 Acc: 0.0380
# running iter=25
# Val Loss: 0.0619 Acc: 0.0394
# running iter=26
# Val Loss: 0.0631 Acc: 0.0411
# running iter=27
# Val Loss: 0.0653 Acc: 0.0427
# running iter=28
# Val Loss: 0.0676 Acc: 0.0443
# running iter=29
# Val Loss: 0.0696 Acc: 0.0459
# running iter=30
# Val Loss: 0.0716 Acc: 0.0474
# running iter=31
# Val Loss: 0.0739 Acc: 0.0489
# running iter=32
# Val Loss: 0.0762 Acc: 0.0505
# running iter=33
# Val Loss: 0.0795 Acc: 0.0519
# running iter=34
# Val Loss: 0.0819 Acc: 0.0533
# running iter=35
# Val Loss: 0.0844 Acc: 0.0549
# running iter=36
# Val Loss: 0.0873 Acc: 0.0563
# running iter=37
# Val Loss: 0.0905 Acc: 0.0579
# running iter=38
# Val Loss: 0.0924 Acc: 0.0594
# running iter=39
# Val Loss: 0.0946 Acc: 0.0610
# running iter=40
# Val Loss: 0.0964 Acc: 0.0626
# running iter=41
# Val Loss: 0.0983 Acc: 0.0642
# running iter=42
# Val Loss: 0.1001 Acc: 0.0659
# running iter=43
# Val Loss: 0.1023 Acc: 0.0675
# running iter=44
# Val Loss: 0.1049 Acc: 0.0689
# running iter=45
# Val Loss: 0.1062 Acc: 0.0706
# running iter=46
# Val Loss: 0.1085 Acc: 0.0722
# running iter=47
# Val Loss: 0.1111 Acc: 0.0737
# running iter=48
# Val Loss: 0.1131 Acc: 0.0753
# running iter=49
# Val Loss: 0.1162 Acc: 0.0767
# running iter=50
# Val Loss: 0.1191 Acc: 0.0782
# running iter=51
# Val Loss: 0.1218 Acc: 0.0796
# running iter=52
# Val Loss: 0.1247 Acc: 0.0811
# running iter=53
# Val Loss: 0.1269 Acc: 0.0828
# running iter=54
# Val Loss: 0.1293 Acc: 0.0843
# running iter=55
# Val Loss: 0.1309 Acc: 0.0860
# running iter=56
# Val Loss: 0.1337 Acc: 0.0875
# running iter=57
# Val Loss: 0.1358 Acc: 0.0891
# running iter=58
# Val Loss: 0.1382 Acc: 0.0907
# running iter=59
# Val Loss: 0.1402 Acc: 0.0922
# running iter=60
# Val Loss: 0.1434 Acc: 0.0936
# running iter=61
# Val Loss: 0.1458 Acc: 0.0951
# running iter=62
# Val Loss: 0.1478 Acc: 0.0966
# running iter=63
# Val Loss: 0.1493 Acc: 0.0983
# running iter=64
# Val Loss: 0.1513 Acc: 0.0998
# running iter=65
# Val Loss: 0.1534 Acc: 0.1014
# running iter=66
# Val Loss: 0.1554 Acc: 0.1030
# running iter=67
# Val Loss: 0.1575 Acc: 0.1045
# running iter=68
# Val Loss: 0.1597 Acc: 0.1061
# running iter=69
# Val Loss: 0.1629 Acc: 0.1075
# running iter=70
# Val Loss: 0.1662 Acc: 0.1090
# running iter=71
# Val Loss: 0.1680 Acc: 0.1106
# running iter=72
# Val Loss: 0.1702 Acc: 0.1121
# running iter=73
# Val Loss: 0.1713 Acc: 0.1139
# running iter=74
# Val Loss: 0.1734 Acc: 0.1155
# running iter=75
# Val Loss: 0.1757 Acc: 0.1171
# running iter=76
# Val Loss: 0.1779 Acc: 0.1186
# running iter=77
# Val Loss: 0.1803 Acc: 0.1201
# running iter=78
# Val Loss: 0.1830 Acc: 0.1216
# running iter=79
# Val Loss: 0.1859 Acc: 0.1229
# running iter=80
# Val Loss: 0.1878 Acc: 0.1245
# running iter=81
# Val Loss: 0.1899 Acc: 0.1261
# running iter=82
# Val Loss: 0.1928 Acc: 0.1276
# running iter=83
# Val Loss: 0.1960 Acc: 0.1290
# running iter=84
# Val Loss: 0.1982 Acc: 0.1306
# running iter=85
# Val Loss: 0.2009 Acc: 0.1321
# running iter=86
# Val Loss: 0.2036 Acc: 0.1335
# running iter=87
# Val Loss: 0.2053 Acc: 0.1351
# running iter=88
# Val Loss: 0.2077 Acc: 0.1366
# running iter=89
# Val Loss: 0.2098 Acc: 0.1382
# running iter=90
# Val Loss: 0.2124 Acc: 0.1397
# running iter=91
# Val Loss: 0.2137 Acc: 0.1414
# running iter=92
# Val Loss: 0.2154 Acc: 0.1429
# running iter=93
# Val Loss: 0.2186 Acc: 0.1444
# running iter=94
# Val Loss: 0.2209 Acc: 0.1458
# running iter=95
# Val Loss: 0.2224 Acc: 0.1474
# running iter=96
# Val Loss: 0.2247 Acc: 0.1489
# running iter=97
# Val Loss: 0.2269 Acc: 0.1503
# running iter=98
# Val Loss: 0.2289 Acc: 0.1519
# running iter=99
# Val Loss: 0.2321 Acc: 0.1534
# validation complete in 0m 24s
# Loss =  0.2320738800764084
# Accuracy =  tensor(0.1534, dtype=torch.float64)

# %%
i = 0
total_c = 10000

inputs = test_data[i*total_c:(i+1)*total_c:,:]
labels = test_labels[i*total_c:(i+1)*total_c]

inputs = torch.from_numpy(inputs)
labels = torch.from_numpy(labels)

inputs = inputs.type(torch.FloatTensor)

with torch.no_grad():
    outputs = trained_model(inputs)
    _, preds = torch.max(outputs, 1)

prob = torch.nn.functional.softmax(outputs, dim=1)
top_p, top_class = prob.topk(1, dim = 1)
top_p = top_p.numpy()

x = heapq.nlargest(5, range(len(top_p)), top_p.take)
y = heapq.nsmallest(5, range(len(top_p)), top_p.take)

for m in range(len(x)):
  print("Confidence = " + str(top_p[x[m]]) + " good - predicted = " + str(label_names[preds[x[m]]]) + " actual = " + str(label_names[test_labels[x[m]]]))

for m in range(len(y)):
  print("Confidence = " + str(top_p[y[m]]) + " bad - predicted = " + str(label_names[preds[y[m]]]) + " actual = " + str(label_names[test_labels[y[m]]]))
# Out:
# Confidence = [1.] good - predicted = b'frog' actual = b'frog'
# Confidence = [1.] good - predicted = b'truck' actual = b'truck'
# Confidence = [1.] good - predicted = b'truck' actual = b'truck'
# Confidence = [1.] good - predicted = b'airplane' actual = b'airplane'
# Confidence = [1.] good - predicted = b'dog' actual = b'dog'
# Confidence = [0.26897067] bad - predicted = b'dog' actual = b'deer'
# Confidence = [0.27327076] bad - predicted = b'dog' actual = b'bird'
# Confidence = [0.2746259] bad - predicted = b'bird' actual = b'deer'
# Confidence = [0.2899105] bad - predicted = b'bird' actual = b'ship'
# Confidence = [0.29362792] bad - predicted = b'frog' actual = b'bird'

# %% [markdown]
# **Clearly there is a trade off between speed vs accuracy between these two models.**
#
# Extracted features
# *   Train Loss: 1.5065 Acc: 0.4794
# *   Training complete in 23m 38s
# *   Val Loss: 0.3138 Acc: 0.0926
# *   Validation complete in 0m 23s
# *   Confidence range : 0.9997893 to 0.13025174
#
# Finetune Features
#
# * Train Loss: 0.0064 Acc: 1.0000
# * Training complete in 101m 1s
# * Val Loss: 0.2321 Acc: 0.1536
# * Validation complete in 0m 26s
# * Confidence range : 1.0 to 0.23327777

# %% [markdown]
# # Problem 2
#
# 2. Instead of embedding words, we will embed movies. In particular, if we can embed movies, then similar movies will be close to each other and can be recommended. This line of reasoning is analogous to the distributional hypothesis of word meanings. For words, this roughly translates to words that appear in similar sentences should have similar vector representations. For movies, vectors for two movies should be similar if they are watched by similar people.
#
#   Let the total number of movies be $M$. Let $X_{i,j}$ be the number of users that liked both movies $i$ and $j$. We want to obtain vectors $v_1,...,v_i,...,v_j,...,v_M$ for all movies such that we minimize the cost $c(v_1,...,v_M) = \sum_{i=1}^{M}\sum_{j=1}^{M}\mathbf{1}_{[i\neq j]}(v_i^Tv_j - X_{i,j})^2$. Here $\mathbf{1}_{[i\neq j]}$ is a function that is $0$ when $i=j$ and $1$ otherwise.

# %% [markdown]
# **PART A:** Compute data $X_{i,j}$ from the movielens (small) dataset and description. Briefly describe your data prep workflow (you can use pandas if needed).

# %%
import pickle
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import pandas as pd
from google.colab import drive
import tensorflow as tf
import torch
import math
import numpy as np

drive.mount('/content/drive')
# %cd /content/drive/My Drive/movielens
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

df = pd.read_csv('ratings.csv')
df = df.drop(columns='timestamp')
df = df[df['rating']> 3.0]
df.reset_index(inplace=True) 
df2 = df.merge(df, how='inner', on='userId')
df3 = df2.pivot_table(index='movieId_x',columns='movieId_y', values='userId', aggfunc='count')
df2 = ""
print(df3)
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/movielens
# movieId_y  1       2       3       5       ...  193583  193585  193587  193609
# movieId_x                                  ...
# 1           165.0    31.0    14.0     8.0  ...     NaN     NaN     NaN     NaN
# 2            31.0    61.0     5.0     4.0  ...     NaN     NaN     NaN     NaN
# 3            14.0     5.0    23.0     4.0  ...     NaN     NaN     NaN     NaN
# 5             8.0     4.0     4.0    13.0  ...     NaN     NaN     NaN     NaN
# 6            32.0    12.0     5.0     3.0  ...     NaN     NaN     NaN     NaN
# ...           ...     ...     ...     ...  ...     ...     ...     ...     ...
# 193581        NaN     NaN     NaN     NaN  ...     1.0     1.0     1.0     NaN
# 193583        NaN     NaN     NaN     NaN  ...     1.0     1.0     1.0     NaN
# 193585        NaN     NaN     NaN     NaN  ...     1.0     1.0     1.0     NaN
# 193587        NaN     NaN     NaN     NaN  ...     1.0     1.0     1.0     NaN
# 193609        NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     1.0
#
# [7363 rows x 7363 columns]

# %% [markdown]
# **Data Prep Workflow**
#
# Our Data Prep and Computations Process were as follows:
#
# Step 1: Loading the necessary packages
#
# Step 2: Connecting the correct Google Drive filepath and reading the data
#
# Step 3: Filtering the data and creating a Pivot Table that calculates the # of users that liked both movies i & j going diagonally across

# %% [markdown]
# **PART B:** Optimize function $c(v_1,...,v_M)$ over $v_1,...,v_M$ using gradient descent (using pytorch or tensorflow). Plot the loss as a function of iteration for various choices (learning rates, choice of optimizers etc).

# %%
import pickle

class Polynomial3(torch.nn.Module):
    def __init__(self):
        """
        In the constructor we instantiate four parameters and assign them as
        member parameters.
        """
        super().__init__()
        self.moviematrix = torch.nn.Parameter(torch.rand(7363, 3))

    def forward(self, m1, m2):
        """
        In the forward function we accept a Tensor of input data and we must return
        a Tensor of output data. We can use Modules defined in the constructor as
        well as arbitrary operators on Tensors.
        """
        a = self.moviematrix[m1]
        b = self.moviematrix[m2]
        c = torch.matmul(a,b)
        #print("c",c)
        #print("m1",m1)
        return c

    def string(self):
        """
        Just like any class in Python, you can also define custom method on PyTorch modules
        """
        return str(self.moviematrix)

def my_loss_fn(y_pred, y_actual):
      d = y_pred - y_actual
      d = d*d
      return d

model = Polynomial3()

# Construct our loss function and an Optimizer. The call to model.parameters()
# in the SGD constructor will contain the learnable parameters of the nn.Linear
# module which is members of the model.
criterion = my_loss_fn
optimizer = torch.optim.SGD(model.parameters(), lr=1e-6)

#df = pd.read_csv('ratings.csv')
#df = df.drop(columns='timestamp')
#df = df[df['rating']> 3.0]
#df.reset_index(inplace=True) 
#df2 = df.merge(df, how='inner', on='userId')
#df3 = df2.pivot_table(index='movieId_x',columns='movieId_y', values='userId', aggfunc='count')

len_matrix = df3.shape[0]
epoch = 1
#len_matrix = 200

for i in range(epoch):
  for p in range(len_matrix):
      for q in range (len_matrix):
          # Forward pass: Compute predicted y by passing x to the model
          y_pred = model(p,q)

          # Compute and print loss
          abc = df3.iat[p,q]
          if np.isnan(abc):
            abc=0
          if p!=q :
            loss = criterion(y_pred, abc)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
          if p % 1000 == 999:
            print(y_pred, abc)

          # Zero gradients, perform a backward pass, and update the weights.


print(f'Result: {model.string()}')

with open('movie_data.pkl', 'wb') as output:
    pickle.dump(model, output, pickle.HIGHEST_PROTOCOL)
# Out:
# Streaming output truncated to the last 5000 lines.
# tensor(0.9202, grad_fn=<DotBackward0>) 0
# tensor(0.3488, grad_fn=<DotBackward0>) 0
# tensor(1.0098, grad_fn=<DotBackward0>) 0
# tensor(0.5781, grad_fn=<DotBackward0>) 0
# tensor(0.9299, grad_fn=<DotBackward0>) 0
# tensor(0.9695, grad_fn=<DotBackward0>) 0
# tensor(1.0563, grad_fn=<DotBackward0>) 0
# tensor(0.6424, grad_fn=<DotBackward0>) 0
# tensor(1.2201, grad_fn=<DotBackward0>) 0
# tensor(0.2250, grad_fn=<DotBackward0>) 0
# tensor(0.3305, grad_fn=<DotBackward0>) 0
# tensor(1.0749, grad_fn=<DotBackward0>) 0
# tensor(0.5742, grad_fn=<DotBackward0>) 0
# tensor(0.2526, grad_fn=<DotBackward0>) 0
# tensor(0.6244, grad_fn=<DotBackward0>) 0
# tensor(0.2457, grad_fn=<DotBackward0>) 0
# tensor(0.7290, grad_fn=<DotBackward0>) 0
# tensor(0.7815, grad_fn=<DotBackward0>) 0
# tensor(0.8541, grad_fn=<DotBackward0>) 0
# tensor(0.2585, grad_fn=<DotBackward0>) 0
# tensor(0.4577, grad_fn=<DotBackward0>) 0
# tensor(0.5036, grad_fn=<DotBackward0>) 0
# tensor(0.2639, grad_fn=<DotBackward0>) 0
# tensor(0.4692, grad_fn=<DotBackward0>) 0
# tensor(0.3955, grad_fn=<DotBackward0>) 0
# tensor(0.8123, grad_fn=<DotBackward0>) 0
# tensor(0.7573, grad_fn=<DotBackward0>) 0
# tensor(0.7314, grad_fn=<DotBackward0>) 0
# tensor(0.9423, grad_fn=<DotBackward0>) 0
# tensor(0.7556, grad_fn=<DotBackward0>) 0
# tensor(0.6181, grad_fn=<DotBackward0>) 0
# tensor(0.3514, grad_fn=<DotBackward0>) 0
# tensor(0.7652, grad_fn=<DotBackward0>) 0
# tensor(0.8952, grad_fn=<DotBackward0>) 0
# tensor(0.4394, grad_fn=<DotBackward0>) 0
# tensor(0.9540, grad_fn=<DotBackward0>) 0
# tensor(0.9021, grad_fn=<DotBackward0>) 0
# tensor(0.5494, grad_fn=<DotBackward0>) 0
# tensor(0.5486, grad_fn=<DotBackward0>) 0
# tensor(0.4354, grad_fn=<DotBackward0>) 0
# tensor(0.4450, grad_fn=<DotBackward0>) 0
# tensor(0.6447, grad_fn=<DotBackward0>) 0
# tensor(0.4008, grad_fn=<DotBackward0>) 0
# tensor(0.4223, grad_fn=<DotBackward0>) 0
# tensor(0.6757, grad_fn=<DotBackward0>) 0
# tensor(0.8799, grad_fn=<DotBackward0>) 0
# tensor(0.9089, grad_fn=<DotBackward0>) 0
# tensor(0.9592, grad_fn=<DotBackward0>) 0
# tensor(0.8045, grad_fn=<DotBackward0>) 0
# tensor(0.5891, grad_fn=<DotBackward0>) 1.0
# tensor(0.9740, grad_fn=<DotBackward0>) 0
# tensor(0.8872, grad_fn=<DotBackward0>) 0
# tensor(0.7996, grad_fn=<DotBackward0>) 0
# tensor(0.6871, grad_fn=<DotBackward0>) 0
# tensor(0.7429, grad_fn=<DotBackward0>) 0
# tensor(0.9298, grad_fn=<DotBackward0>) 0
# tensor(0.5094, grad_fn=<DotBackward0>) 0
# tensor(0.9355, grad_fn=<DotBackward0>) 0
# tensor(0.5934, grad_fn=<DotBackward0>) 0
# tensor(0.3044, grad_fn=<DotBackward0>) 0
# tensor(0.5303, grad_fn=<DotBackward0>) 0
# tensor(0.5492, grad_fn=<DotBackward0>) 0
# tensor(0.8901, grad_fn=<DotBackward0>) 0
# tensor(0.9467, grad_fn=<DotBackward0>) 0
# tensor(0.6724, grad_fn=<DotBackward0>) 0
# tensor(0.8797, grad_fn=<DotBackward0>) 0
# tensor(0.6205, grad_fn=<DotBackward0>) 0
# tensor(0.9977, grad_fn=<DotBackward0>) 0
# tensor(0.5679, grad_fn=<DotBackward0>) 0
# tensor(1.0290, grad_fn=<DotBackward0>) 0
# tensor(0.8664, grad_fn=<DotBackward0>) 0
# tensor(0.4680, grad_fn=<DotBackward0>) 0
# tensor(0.5337, grad_fn=<DotBackward0>) 0
# tensor(0.3961, grad_fn=<DotBackward0>) 0
# tensor(0.8453, grad_fn=<DotBackward0>) 0
# tensor(1.0991, grad_fn=<DotBackward0>) 0
# tensor(0.6393, grad_fn=<DotBackward0>) 1.0
# tensor(0.4804, grad_fn=<DotBackward0>) 0
# tensor(0.5934, grad_fn=<DotBackward0>) 0
# tensor(0.7766, grad_fn=<DotBackward0>) 0
# tensor(0.8075, grad_fn=<DotBackward0>) 0
# tensor(0.5156, grad_fn=<DotBackward0>) 0
# tensor(0.5052, grad_fn=<DotBackward0>) 0
# tensor(0.3580, grad_fn=<DotBackward0>) 0
# tensor(0.4532, grad_fn=<DotBackward0>) 0
# tensor(0.1945, grad_fn=<DotBackward0>) 0
# tensor(0.8204, grad_fn=<DotBackward0>) 0
# tensor(0.6765, grad_fn=<DotBackward0>) 0
# tensor(0.4367, grad_fn=<DotBackward0>) 0
# tensor(0.7255, grad_fn=<DotBackward0>) 0
# tensor(0.6912, grad_fn=<DotBackward0>) 0
# tensor(0.7241, grad_fn=<DotBackward0>) 0
# tensor(0.6510, grad_fn=<DotBackward0>) 0
# tensor(0.9086, grad_fn=<DotBackward0>) 0
# tensor(1.0205, grad_fn=<DotBackward0>) 0
# tensor(0.7490, grad_fn=<DotBackward0>) 0
# tensor(0.6063, grad_fn=<DotBackward0>) 0
# tensor(0.5227, grad_fn=<DotBackward0>) 0
# tensor(1.0063, grad_fn=<DotBackward0>) 0
# tensor(0.9647, grad_fn=<DotBackward0>) 0
# tensor(0.5086, grad_fn=<DotBackward0>) 0
# tensor(0.5466, grad_fn=<DotBackward0>) 0
# tensor(0.4872, grad_fn=<DotBackward0>) 0
# tensor(0.9067, grad_fn=<DotBackward0>) 0
# tensor(0.6609, grad_fn=<DotBackward0>) 0
# tensor(0.6752, grad_fn=<DotBackward0>) 0
# tensor(0.6971, grad_fn=<DotBackward0>) 0
# tensor(0.9162, grad_fn=<DotBackward0>) 0
# tensor(0.5674, grad_fn=<DotBackward0>) 0
# tensor(0.7835, grad_fn=<DotBackward0>) 0
# tensor(0.6117, grad_fn=<DotBackward0>) 0
# tensor(0.3871, grad_fn=<DotBackward0>) 0
# tensor(0.6335, grad_fn=<DotBackward0>) 0
# tensor(0.9850, grad_fn=<DotBackward0>) 0
# tensor(0.3171, grad_fn=<DotBackward0>) 0
# tensor(0.5053, grad_fn=<DotBackward0>) 0
# tensor(0.3173, grad_fn=<DotBackward0>) 0
# tensor(0.8378, grad_fn=<DotBackward0>) 0
# tensor(0.6963, grad_fn=<DotBackward0>) 0
# tensor(0.6406, grad_fn=<DotBackward0>) 0
# tensor(0.9107, grad_fn=<DotBackward0>) 0
# tensor(0.5361, grad_fn=<DotBackward0>) 0
# tensor(0.5804, grad_fn=<DotBackward0>) 0
# tensor(0.7098, grad_fn=<DotBackward0>) 0
# tensor(0.8372, grad_fn=<DotBackward0>) 0
# tensor(0.8448, grad_fn=<DotBackward0>) 0
# tensor(0.8329, grad_fn=<DotBackward0>) 0
# tensor(0.3695, grad_fn=<DotBackward0>) 0
# tensor(0.6826, grad_fn=<DotBackward0>) 0
# tensor(0.6480, grad_fn=<DotBackward0>) 0
# tensor(0.5735, grad_fn=<DotBackward0>) 0
# tensor(0.6127, grad_fn=<DotBackward0>) 0
# tensor(0.4250, grad_fn=<DotBackward0>) 0
# tensor(0.6495, grad_fn=<DotBackward0>) 0
# tensor(0.7610, grad_fn=<DotBackward0>) 0
# tensor(0.6219, grad_fn=<DotBackward0>) 0
# tensor(0.4153, grad_fn=<DotBackward0>) 0
# tensor(0.2954, grad_fn=<DotBackward0>) 0
# tensor(0.8701, grad_fn=<DotBackward0>) 0
# tensor(1.1562, grad_fn=<DotBackward0>) 0
# tensor(0.6455, grad_fn=<DotBackward0>) 0
# tensor(0.5642, grad_fn=<DotBackward0>) 0
# tensor(0.5013, grad_fn=<DotBackward0>) 0
# tensor(0.5138, grad_fn=<DotBackward0>) 0
# tensor(0.6549, grad_fn=<DotBackward0>) 0
# tensor(0.8475, grad_fn=<DotBackward0>) 0
# tensor(0.2718, grad_fn=<DotBackward0>) 0
# tensor(0.7661, grad_fn=<DotBackward0>) 0
# tensor(1.0740, grad_fn=<DotBackward0>) 0
# tensor(0.6652, grad_fn=<DotBackward0>) 0
# tensor(0.4041, grad_fn=<DotBackward0>) 0
# tensor(0.5398, grad_fn=<DotBackward0>) 0
# tensor(0.5706, grad_fn=<DotBackward0>) 0
# tensor(0.3584, grad_fn=<DotBackward0>) 0
# tensor(0.5128, grad_fn=<DotBackward0>) 0
# tensor(1.0791, grad_fn=<DotBackward0>) 0
# tensor(0.5141, grad_fn=<DotBackward0>) 0
# tensor(0.4906, grad_fn=<DotBackward0>) 0
# tensor(0.7911, grad_fn=<DotBackward0>) 0
# tensor(0.2210, grad_fn=<DotBackward0>) 0
# tensor(0.6153, grad_fn=<DotBackward0>) 0
# tensor(0.9197, grad_fn=<DotBackward0>) 0
# tensor(0.7070, grad_fn=<DotBackward0>) 0
# tensor(0.5833, grad_fn=<DotBackward0>) 0
# tensor(0.6228, grad_fn=<DotBackward0>) 0
# tensor(0.2023, grad_fn=<DotBackward0>) 0
# tensor(0.6805, grad_fn=<DotBackward0>) 0
# tensor(0.4042, grad_fn=<DotBackward0>) 0
# tensor(0.3359, grad_fn=<DotBackward0>) 0
# tensor(0.4989, grad_fn=<DotBackward0>) 0
# tensor(0.6619, grad_fn=<DotBackward0>) 0
# tensor(0.6675, grad_fn=<DotBackward0>) 0
# tensor(0.6965, grad_fn=<DotBackward0>) 0
# tensor(1.1170, grad_fn=<DotBackward0>) 0
# tensor(0.5712, grad_fn=<DotBackward0>) 0
# tensor(0.6838, grad_fn=<DotBackward0>) 0
# tensor(0.2565, grad_fn=<DotBackward0>) 0
# tensor(0.6279, grad_fn=<DotBackward0>) 0
# tensor(0.2143, grad_fn=<DotBackward0>) 0
# tensor(0.9504, grad_fn=<DotBackward0>) 0
# tensor(0.5386, grad_fn=<DotBackward0>) 0
# tensor(0.9196, grad_fn=<DotBackward0>) 0
# tensor(0.5770, grad_fn=<DotBackward0>) 0
# tensor(0.3439, grad_fn=<DotBackward0>) 0
# tensor(0.3913, grad_fn=<DotBackward0>) 0
# tensor(0.7687, grad_fn=<DotBackward0>) 0
# tensor(1.0208, grad_fn=<DotBackward0>) 0
# tensor(0.8002, grad_fn=<DotBackward0>) 0
# tensor(0.3205, grad_fn=<DotBackward0>) 0
# tensor(0.9860, grad_fn=<DotBackward0>) 0
# tensor(0.4565, grad_fn=<DotBackward0>) 0
# tensor(0.9268, grad_fn=<DotBackward0>) 0
# tensor(0.4526, grad_fn=<DotBackward0>) 0
# tensor(0.5488, grad_fn=<DotBackward0>) 0
# tensor(0.6000, grad_fn=<DotBackward0>) 0
# tensor(0.5686, grad_fn=<DotBackward0>) 0
# tensor(1.0091, grad_fn=<DotBackward0>) 0
# tensor(0.7115, grad_fn=<DotBackward0>) 0
# tensor(0.3301, grad_fn=<DotBackward0>) 0
# tensor(0.6732, grad_fn=<DotBackward0>) 0
# tensor(0.4067, grad_fn=<DotBackward0>) 0
# tensor(0.7274, grad_fn=<DotBackward0>) 0
# tensor(0.3830, grad_fn=<DotBackward0>) 0
# tensor(0.6564, grad_fn=<DotBackward0>) 0
# tensor(0.7637, grad_fn=<DotBackward0>) 0
# tensor(0.6468, grad_fn=<DotBackward0>) 0
# tensor(0.6209, grad_fn=<DotBackward0>) 0
# tensor(0.6202, grad_fn=<DotBackward0>) 0
# tensor(0.4039, grad_fn=<DotBackward0>) 0
# tensor(1.0629, grad_fn=<DotBackward0>) 0
# tensor(0.8295, grad_fn=<DotBackward0>) 0
# tensor(0.6987, grad_fn=<DotBackward0>) 0
# tensor(0.4742, grad_fn=<DotBackward0>) 0
# tensor(0.4547, grad_fn=<DotBackward0>) 0
# tensor(0.6963, grad_fn=<DotBackward0>) 0
# tensor(0.4164, grad_fn=<DotBackward0>) 0
# tensor(0.5402, grad_fn=<DotBackward0>) 0
# tensor(0.5817, grad_fn=<DotBackward0>) 0
# tensor(0.6939, grad_fn=<DotBackward0>) 0
# tensor(0.6984, grad_fn=<DotBackward0>) 0
# tensor(0.5927, grad_fn=<DotBackward0>) 0
# tensor(0.6218, grad_fn=<DotBackward0>) 0
# tensor(0.9243, grad_fn=<DotBackward0>) 0
# tensor(0.3447, grad_fn=<DotBackward0>) 0
# tensor(0.3929, grad_fn=<DotBackward0>) 0
# tensor(1.1119, grad_fn=<DotBackward0>) 0
# tensor(0.3170, grad_fn=<DotBackward0>) 0
# tensor(0.8033, grad_fn=<DotBackward0>) 0
# tensor(0.7907, grad_fn=<DotBackward0>) 0
# tensor(0.6074, grad_fn=<DotBackward0>) 0
# tensor(0.4112, grad_fn=<DotBackward0>) 0
# tensor(0.2105, grad_fn=<DotBackward0>) 0
# tensor(0.3777, grad_fn=<DotBackward0>) 0
# tensor(0.5794, grad_fn=<DotBackward0>) 0
# tensor(0.6574, grad_fn=<DotBackward0>) 1.0
# tensor(0.6466, grad_fn=<DotBackward0>) 0
# tensor(0.7325, grad_fn=<DotBackward0>) 0
# tensor(0.8024, grad_fn=<DotBackward0>) 0
# tensor(0.4307, grad_fn=<DotBackward0>) 0
# tensor(0.6614, grad_fn=<DotBackward0>) 0
# tensor(0.9473, grad_fn=<DotBackward0>) 0
# tensor(0.6735, grad_fn=<DotBackward0>) 0
# tensor(0.6841, grad_fn=<DotBackward0>) 0
# tensor(0.6572, grad_fn=<DotBackward0>) 0
# tensor(0.4761, grad_fn=<DotBackward0>) 0
# tensor(1.0232, grad_fn=<DotBackward0>) 0
# tensor(1.0741, grad_fn=<DotBackward0>) 0
# tensor(1.1765, grad_fn=<DotBackward0>) 0
# tensor(0.5700, grad_fn=<DotBackward0>) 0
# tensor(0.6679, grad_fn=<DotBackward0>) 0
# tensor(0.9492, grad_fn=<DotBackward0>) 0
# tensor(0.3366, grad_fn=<DotBackward0>) 0
# tensor(0.4581, grad_fn=<DotBackward0>) 0
# tensor(0.1200, grad_fn=<DotBackward0>) 0
# tensor(1.2443, grad_fn=<DotBackward0>) 0
# tensor(0.6522, grad_fn=<DotBackward0>) 0
# tensor(0.7271, grad_fn=<DotBackward0>) 0
# tensor(0.8856, grad_fn=<DotBackward0>) 0
# tensor(0.7101, grad_fn=<DotBackward0>) 0
# tensor(1.0564, grad_fn=<DotBackward0>) 0
# tensor(0.4109, grad_fn=<DotBackward0>) 0
# tensor(0.4605, grad_fn=<DotBackward0>) 0
# tensor(0.7503, grad_fn=<DotBackward0>) 0
# tensor(0.6433, grad_fn=<DotBackward0>) 0
# tensor(0.8995, grad_fn=<DotBackward0>) 0
# tensor(0.2234, grad_fn=<DotBackward0>) 0
# tensor(0.7024, grad_fn=<DotBackward0>) 0
# tensor(1.1888, grad_fn=<DotBackward0>) 0
# tensor(0.5819, grad_fn=<DotBackward0>) 0
# tensor(0.6077, grad_fn=<DotBackward0>) 0
# tensor(0.8024, grad_fn=<DotBackward0>) 0
# tensor(0.5984, grad_fn=<DotBackward0>) 0
# tensor(0.6248, grad_fn=<DotBackward0>) 0
# tensor(0.8478, grad_fn=<DotBackward0>) 0
# tensor(0.4722, grad_fn=<DotBackward0>) 0
# tensor(0.3484, grad_fn=<DotBackward0>) 0
# tensor(0.4826, grad_fn=<DotBackward0>) 0
# tensor(0.8272, grad_fn=<DotBackward0>) 0
# tensor(0.9578, grad_fn=<DotBackward0>) 0
# tensor(0.4006, grad_fn=<DotBackward0>) 0
# tensor(0.8851, grad_fn=<DotBackward0>) 0
# tensor(0.6297, grad_fn=<DotBackward0>) 0
# tensor(0.9652, grad_fn=<DotBackward0>) 0
# tensor(0.6100, grad_fn=<DotBackward0>) 0
# tensor(0.4347, grad_fn=<DotBackward0>) 0
# tensor(0.4928, grad_fn=<DotBackward0>) 0
# tensor(0.6475, grad_fn=<DotBackward0>) 0
# tensor(0.7406, grad_fn=<DotBackward0>) 0
# tensor(0.7930, grad_fn=<DotBackward0>) 0
# tensor(0.8202, grad_fn=<DotBackward0>) 0
# tensor(0.8887, grad_fn=<DotBackward0>) 0
# tensor(0.8736, grad_fn=<DotBackward0>) 0
# tensor(0.6934, grad_fn=<DotBackward0>) 0
# tensor(0.5982, grad_fn=<DotBackward0>) 0
# tensor(0.7699, grad_fn=<DotBackward0>) 0
# tensor(0.6207, grad_fn=<DotBackward0>) 0
# tensor(1.2162, grad_fn=<DotBackward0>) 0
# tensor(0.9901, grad_fn=<DotBackward0>) 0
# tensor(0.7137, grad_fn=<DotBackward0>) 0
# tensor(0.9297, grad_fn=<DotBackward0>) 0
# tensor(0.9504, grad_fn=<DotBackward0>) 0
# tensor(0.8262, grad_fn=<DotBackward0>) 0
# tensor(0.5275, grad_fn=<DotBackward0>) 0
# tensor(0.9744, grad_fn=<DotBackward0>) 0
# tensor(0.6762, grad_fn=<DotBackward0>) 0
# tensor(0.9023, grad_fn=<DotBackward0>) 0
# tensor(0.4681, grad_fn=<DotBackward0>) 0
# tensor(0.8301, grad_fn=<DotBackward0>) 0
# tensor(0.8283, grad_fn=<DotBackward0>) 0
# tensor(0.6466, grad_fn=<DotBackward0>) 0
# tensor(0.2662, grad_fn=<DotBackward0>) 0
# tensor(0.8861, grad_fn=<DotBackward0>) 0
# tensor(0.4821, grad_fn=<DotBackward0>) 0
# tensor(0.8039, grad_fn=<DotBackward0>) 0
# tensor(0.4724, grad_fn=<DotBackward0>) 0
# tensor(0.6542, grad_fn=<DotBackward0>) 0
# tensor(0.2686, grad_fn=<DotBackward0>) 0
# tensor(0.7592, grad_fn=<DotBackward0>) 0
# tensor(0.5797, grad_fn=<DotBackward0>) 0
# tensor(0.8906, grad_fn=<DotBackward0>) 0
# tensor(0.6765, grad_fn=<DotBackward0>) 0
# tensor(0.4209, grad_fn=<DotBackward0>) 0
# tensor(0.9040, grad_fn=<DotBackward0>) 0
# tensor(0.4044, grad_fn=<DotBackward0>) 0
# tensor(0.5695, grad_fn=<DotBackward0>) 0
# tensor(0.4201, grad_fn=<DotBackward0>) 0
# tensor(0.3949, grad_fn=<DotBackward0>) 0
# tensor(0.6872, grad_fn=<DotBackward0>) 0
# tensor(0.3885, grad_fn=<DotBackward0>) 0
# tensor(0.9226, grad_fn=<DotBackward0>) 0
# tensor(0.5720, grad_fn=<DotBackward0>) 0
# tensor(0.4796, grad_fn=<DotBackward0>) 0
# tensor(0.9374, grad_fn=<DotBackward0>) 0
# tensor(0.4270, grad_fn=<DotBackward0>) 0
# tensor(0.5257, grad_fn=<DotBackward0>) 0
# tensor(0.3160, grad_fn=<DotBackward0>) 0
# tensor(0.5363, grad_fn=<DotBackward0>) 0
# tensor(0.6148, grad_fn=<DotBackward0>) 0
# tensor(1.0023, grad_fn=<DotBackward0>) 0
# tensor(0.8879, grad_fn=<DotBackward0>) 0
# tensor(0.5763, grad_fn=<DotBackward0>) 0
# tensor(0.6456, grad_fn=<DotBackward0>) 0
# tensor(0.8688, grad_fn=<DotBackward0>) 0
# tensor(0.4267, grad_fn=<DotBackward0>) 0
# tensor(0.4528, grad_fn=<DotBackward0>) 0
# tensor(0.4247, grad_fn=<DotBackward0>) 0
# tensor(0.7339, grad_fn=<DotBackward0>) 0
# tensor(0.5918, grad_fn=<DotBackward0>) 0
# tensor(0.5405, grad_fn=<DotBackward0>) 0
# tensor(0.6626, grad_fn=<DotBackward0>) 0
# tensor(0.8043, grad_fn=<DotBackward0>) 0
# tensor(0.8728, grad_fn=<DotBackward0>) 0
# tensor(0.7906, grad_fn=<DotBackward0>) 0
# tensor(0.4748, grad_fn=<DotBackward0>) 0
# tensor(0.6765, grad_fn=<DotBackward0>) 0
# tensor(0.7222, grad_fn=<DotBackward0>) 0
# tensor(0.5010, grad_fn=<DotBackward0>) 0
# tensor(0.4230, grad_fn=<DotBackward0>) 0
# tensor(0.5949, grad_fn=<DotBackward0>) 0
# tensor(0.1091, grad_fn=<DotBackward0>) 0
# tensor(0.4579, grad_fn=<DotBackward0>) 0
# tensor(0.7167, grad_fn=<DotBackward0>) 0
# tensor(0.1881, grad_fn=<DotBackward0>) 0
# tensor(1.0515, grad_fn=<DotBackward0>) 0
# tensor(0.5627, grad_fn=<DotBackward0>) 0
# tensor(0.6999, grad_fn=<DotBackward0>) 0
# tensor(0.9817, grad_fn=<DotBackward0>) 0
# tensor(1.0071, grad_fn=<DotBackward0>) 0
# tensor(0.8811, grad_fn=<DotBackward0>) 0
# tensor(0.3286, grad_fn=<DotBackward0>) 0
# tensor(0.1515, grad_fn=<DotBackward0>) 0
# tensor(1.0921, grad_fn=<DotBackward0>) 0
# tensor(0.7175, grad_fn=<DotBackward0>) 0
# tensor(0.7996, grad_fn=<DotBackward0>) 0
# tensor(0.4680, grad_fn=<DotBackward0>) 0
# tensor(0.7009, grad_fn=<DotBackward0>) 0
# tensor(0.8107, grad_fn=<DotBackward0>) 0
# tensor(0.4465, grad_fn=<DotBackward0>) 0
# tensor(0.6770, grad_fn=<DotBackward0>) 0
# tensor(0.9497, grad_fn=<DotBackward0>) 0
# tensor(0.4117, grad_fn=<DotBackward0>) 0
# tensor(1.1383, grad_fn=<DotBackward0>) 0
# tensor(0.3060, grad_fn=<DotBackward0>) 0
# tensor(0.5507, grad_fn=<DotBackward0>) 0
# tensor(0.7714, grad_fn=<DotBackward0>) 0
# tensor(0.8367, grad_fn=<DotBackward0>) 0
# tensor(0.6839, grad_fn=<DotBackward0>) 0
# tensor(0.5022, grad_fn=<DotBackward0>) 0
# tensor(0.5750, grad_fn=<DotBackward0>) 0
# tensor(0.9394, grad_fn=<DotBackward0>) 0
# tensor(0.5064, grad_fn=<DotBackward0>) 0
# tensor(1.1336, grad_fn=<DotBackward0>) 0
# tensor(0.6127, grad_fn=<DotBackward0>) 0
# tensor(0.7402, grad_fn=<DotBackward0>) 0
# tensor(0.6321, grad_fn=<DotBackward0>) 0
# tensor(1.0278, grad_fn=<DotBackward0>) 0
# tensor(1.2513, grad_fn=<DotBackward0>) 0
# tensor(0.7412, grad_fn=<DotBackward0>) 0
# tensor(0.6275, grad_fn=<DotBackward0>) 0
# tensor(0.9841, grad_fn=<DotBackward0>) 0
# tensor(0.5975, grad_fn=<DotBackward0>) 0
# tensor(0.2549, grad_fn=<DotBackward0>) 0
# tensor(0.9593, grad_fn=<DotBackward0>) 0
# tensor(0.8332, grad_fn=<DotBackward0>) 0
# tensor(0.7583, grad_fn=<DotBackward0>) 0
# tensor(0.2758, grad_fn=<DotBackward0>) 0
# tensor(1.0438, grad_fn=<DotBackward0>) 0
# tensor(0.5619, grad_fn=<DotBackward0>) 0
# tensor(0.7543, grad_fn=<DotBackward0>) 0
# tensor(0.9118, grad_fn=<DotBackward0>) 0
# tensor(0.8379, grad_fn=<DotBackward0>) 0
# tensor(0.8191, grad_fn=<DotBackward0>) 0
# tensor(0.7195, grad_fn=<DotBackward0>) 0
# tensor(0.9446, grad_fn=<DotBackward0>) 0
# tensor(1.1743, grad_fn=<DotBackward0>) 0
# tensor(0.4813, grad_fn=<DotBackward0>) 0
# tensor(0.5868, grad_fn=<DotBackward0>) 0
# tensor(0.6685, grad_fn=<DotBackward0>) 0
# tensor(1.2523, grad_fn=<DotBackward0>) 0
# tensor(0.3776, grad_fn=<DotBackward0>) 1.0
# tensor(0.7018, grad_fn=<DotBackward0>) 0
# tensor(0.6391, grad_fn=<DotBackward0>) 0
# tensor(0.5363, grad_fn=<DotBackward0>) 0
# tensor(0.7039, grad_fn=<DotBackward0>) 0
# tensor(0.6403, grad_fn=<DotBackward0>) 0
# tensor(0.4898, grad_fn=<DotBackward0>) 0
# tensor(0.6720, grad_fn=<DotBackward0>) 0
# tensor(0.9735, grad_fn=<DotBackward0>) 0
# tensor(0.5047, grad_fn=<DotBackward0>) 0
# tensor(0.7803, grad_fn=<DotBackward0>) 0
# tensor(0.5176, grad_fn=<DotBackward0>) 0
# tensor(0.6148, grad_fn=<DotBackward0>) 0
# tensor(0.3406, grad_fn=<DotBackward0>) 0
# tensor(0.5631, grad_fn=<DotBackward0>) 0
# tensor(1.0240, grad_fn=<DotBackward0>) 0
# tensor(0.6334, grad_fn=<DotBackward0>) 0
# tensor(0.5463, grad_fn=<DotBackward0>) 0
# tensor(0.7603, grad_fn=<DotBackward0>) 0
# tensor(0.6802, grad_fn=<DotBackward0>) 0
# tensor(0.5071, grad_fn=<DotBackward0>) 0
# tensor(0.7872, grad_fn=<DotBackward0>) 0
# tensor(0.9923, grad_fn=<DotBackward0>) 0
# tensor(0.6758, grad_fn=<DotBackward0>) 0
# tensor(0.7500, grad_fn=<DotBackward0>) 0
# tensor(0.8671, grad_fn=<DotBackward0>) 0
# tensor(0.8404, grad_fn=<DotBackward0>) 0
# tensor(0.6637, grad_fn=<DotBackward0>) 0
# tensor(0.4464, grad_fn=<DotBackward0>) 0
# tensor(0.5007, grad_fn=<DotBackward0>) 0
# tensor(0.7701, grad_fn=<DotBackward0>) 0
# tensor(0.4921, grad_fn=<DotBackward0>) 0
# tensor(0.6109, grad_fn=<DotBackward0>) 0
# tensor(0.9647, grad_fn=<DotBackward0>) 0
# tensor(0.0603, grad_fn=<DotBackward0>) 0
# tensor(0.6248, grad_fn=<DotBackward0>) 0
# tensor(0.9053, grad_fn=<DotBackward0>) 0
# tensor(0.5984, grad_fn=<DotBackward0>) 0
# tensor(0.9842, grad_fn=<DotBackward0>) 0
# tensor(0.5167, grad_fn=<DotBackward0>) 0
# tensor(0.5028, grad_fn=<DotBackward0>) 0
# tensor(0.5367, grad_fn=<DotBackward0>) 0
# tensor(0.7021, grad_fn=<DotBackward0>) 0
# tensor(0.7977, grad_fn=<DotBackward0>) 0
# tensor(0.8408, grad_fn=<DotBackward0>) 0
# tensor(0.8623, grad_fn=<DotBackward0>) 0
# tensor(0.6353, grad_fn=<DotBackward0>) 0
# tensor(0.8191, grad_fn=<DotBackward0>) 0
# tensor(0.6852, grad_fn=<DotBackward0>) 0
# tensor(0.5722, grad_fn=<DotBackward0>) 0
# tensor(1.0081, grad_fn=<DotBackward0>) 0
# tensor(0.5918, grad_fn=<DotBackward0>) 0
# tensor(0.1419, grad_fn=<DotBackward0>) 0
# tensor(0.7683, grad_fn=<DotBackward0>) 0
# tensor(0.4882, grad_fn=<DotBackward0>) 0
# tensor(0.7499, grad_fn=<DotBackward0>) 0
# tensor(0.6297, grad_fn=<DotBackward0>) 0
# tensor(0.8401, grad_fn=<DotBackward0>) 0
# tensor(0.3516, grad_fn=<DotBackward0>) 0
# tensor(1.0398, grad_fn=<DotBackward0>) 0
# tensor(0.1808, grad_fn=<DotBackward0>) 0
# tensor(0.9695, grad_fn=<DotBackward0>) 0
# tensor(1.0723, grad_fn=<DotBackward0>) 0
# tensor(1.0403, grad_fn=<DotBackward0>) 0
# tensor(0.6697, grad_fn=<DotBackward0>) 0
# tensor(0.4054, grad_fn=<DotBackward0>) 0
# tensor(0.2834, grad_fn=<DotBackward0>) 0
# tensor(0.5164, grad_fn=<DotBackward0>) 0
# tensor(0.7791, grad_fn=<DotBackward0>) 0
# tensor(0.9777, grad_fn=<DotBackward0>) 0
# tensor(0.7380, grad_fn=<DotBackward0>) 0
# tensor(0.9838, grad_fn=<DotBackward0>) 0
# tensor(0.5750, grad_fn=<DotBackward0>) 0
# tensor(0.6012, grad_fn=<DotBackward0>) 0
# tensor(0.7616, grad_fn=<DotBackward0>) 0
# tensor(1.2115, grad_fn=<DotBackward0>) 0
# tensor(1.0111, grad_fn=<DotBackward0>) 0
# tensor(0.9687, grad_fn=<DotBackward0>) 0
# tensor(1.1225, grad_fn=<DotBackward0>) 0
# tensor(0.8095, grad_fn=<DotBackward0>) 0
# tensor(1.0101, grad_fn=<DotBackward0>) 0
# tensor(0.5739, grad_fn=<DotBackward0>) 0
# tensor(0.6694, grad_fn=<DotBackward0>) 0
# tensor(0.8585, grad_fn=<DotBackward0>) 0
# tensor(0.5117, grad_fn=<DotBackward0>) 1.0
# tensor(0.4797, grad_fn=<DotBackward0>) 0
# tensor(0.9351, grad_fn=<DotBackward0>) 0
# tensor(0.3173, grad_fn=<DotBackward0>) 0
# tensor(0.5254, grad_fn=<DotBackward0>) 0
# tensor(0.6500, grad_fn=<DotBackward0>) 0
# tensor(0.7314, grad_fn=<DotBackward0>) 0
# tensor(1.0618, grad_fn=<DotBackward0>) 0
# tensor(0.8866, grad_fn=<DotBackward0>) 0
# tensor(0.7425, grad_fn=<DotBackward0>) 0
# tensor(0.2806, grad_fn=<DotBackward0>) 0
# tensor(0.9143, grad_fn=<DotBackward0>) 0
# tensor(0.6795, grad_fn=<DotBackward0>) 0
# tensor(0.5283, grad_fn=<DotBackward0>) 0
# tensor(0.7211, grad_fn=<DotBackward0>) 0
# tensor(0.8540, grad_fn=<DotBackward0>) 0
# tensor(0.4874, grad_fn=<DotBackward0>) 0
# tensor(0.7413, grad_fn=<DotBackward0>) 0
# tensor(0.9063, grad_fn=<DotBackward0>) 0
# tensor(0.8415, grad_fn=<DotBackward0>) 0
# tensor(0.6687, grad_fn=<DotBackward0>) 0
# tensor(0.8516, grad_fn=<DotBackward0>) 0
# tensor(0.8213, grad_fn=<DotBackward0>) 0
# tensor(0.3251, grad_fn=<DotBackward0>) 0
# tensor(1.0483, grad_fn=<DotBackward0>) 0
# tensor(0.7701, grad_fn=<DotBackward0>) 0
# tensor(0.5740, grad_fn=<DotBackward0>) 0
# tensor(0.6107, grad_fn=<DotBackward0>) 0
# tensor(0.6662, grad_fn=<DotBackward0>) 0
# tensor(0.4447, grad_fn=<DotBackward0>) 0
# tensor(0.7623, grad_fn=<DotBackward0>) 0
# tensor(0.7571, grad_fn=<DotBackward0>) 0
# tensor(0.1934, grad_fn=<DotBackward0>) 0
# tensor(1.0148, grad_fn=<DotBackward0>) 0
# tensor(0.4480, grad_fn=<DotBackward0>) 0
# tensor(0.8268, grad_fn=<DotBackward0>) 0
# tensor(0.5037, grad_fn=<DotBackward0>) 0
# tensor(0.9634, grad_fn=<DotBackward0>) 0
# tensor(0.4732, grad_fn=<DotBackward0>) 0
# tensor(0.8876, grad_fn=<DotBackward0>) 0
# tensor(0.5570, grad_fn=<DotBackward0>) 0
# tensor(0.5758, grad_fn=<DotBackward0>) 0
# tensor(1.2360, grad_fn=<DotBackward0>) 0
# tensor(0.4425, grad_fn=<DotBackward0>) 0
# tensor(0.8285, grad_fn=<DotBackward0>) 0
# tensor(0.5864, grad_fn=<DotBackward0>) 0
# tensor(0.8535, grad_fn=<DotBackward0>) 0
# tensor(0.5954, grad_fn=<DotBackward0>) 0
# tensor(0.4113, grad_fn=<DotBackward0>) 0
# tensor(0.7884, grad_fn=<DotBackward0>) 0
# tensor(0.5456, grad_fn=<DotBackward0>) 0
# tensor(0.9839, grad_fn=<DotBackward0>) 0
# tensor(0.5464, grad_fn=<DotBackward0>) 0
# tensor(0.8225, grad_fn=<DotBackward0>) 0
# tensor(0.5439, grad_fn=<DotBackward0>) 0
# tensor(0.6599, grad_fn=<DotBackward0>) 0
# tensor(0.7365, grad_fn=<DotBackward0>) 0
# tensor(1.0604, grad_fn=<DotBackward0>) 0
# tensor(0.5815, grad_fn=<DotBackward0>) 0
# tensor(0.4282, grad_fn=<DotBackward0>) 0
# tensor(0.6486, grad_fn=<DotBackward0>) 0
# tensor(0.4399, grad_fn=<DotBackward0>) 0
# tensor(0.6603, grad_fn=<DotBackward0>) 0
# tensor(1.0428, grad_fn=<DotBackward0>) 0
# tensor(0.7940, grad_fn=<DotBackward0>) 0
# tensor(0.5196, grad_fn=<DotBackward0>) 0
# tensor(0.8190, grad_fn=<DotBackward0>) 0
# tensor(0.5204, grad_fn=<DotBackward0>) 0
# tensor(1.1349, grad_fn=<DotBackward0>) 0
# tensor(0.6486, grad_fn=<DotBackward0>) 0
# tensor(0.5965, grad_fn=<DotBackward0>) 0
# tensor(0.9341, grad_fn=<DotBackward0>) 0
# tensor(0.7711, grad_fn=<DotBackward0>) 0
# tensor(0.6661, grad_fn=<DotBackward0>) 0
# tensor(0.5506, grad_fn=<DotBackward0>) 0
# tensor(0.5797, grad_fn=<DotBackward0>) 0
# tensor(0.7218, grad_fn=<DotBackward0>) 1.0
# tensor(0.7607, grad_fn=<DotBackward0>) 0
# tensor(0.5594, grad_fn=<DotBackward0>) 0
# tensor(0.5173, grad_fn=<DotBackward0>) 0
# tensor(0.6878, grad_fn=<DotBackward0>) 0
# tensor(0.7391, grad_fn=<DotBackward0>) 0
# tensor(0.8569, grad_fn=<DotBackward0>) 0
# tensor(0.4967, grad_fn=<DotBackward0>) 0
# tensor(0.5607, grad_fn=<DotBackward0>) 0
# tensor(0.5029, grad_fn=<DotBackward0>) 0
# tensor(0.4691, grad_fn=<DotBackward0>) 0
# tensor(0.9473, grad_fn=<DotBackward0>) 0
# tensor(0.7984, grad_fn=<DotBackward0>) 0
# tensor(0.7239, grad_fn=<DotBackward0>) 0
# tensor(0.7175, grad_fn=<DotBackward0>) 0
# tensor(0.9072, grad_fn=<DotBackward0>) 0
# tensor(0.5554, grad_fn=<DotBackward0>) 0
# tensor(0.2131, grad_fn=<DotBackward0>) 0
# tensor(0.3235, grad_fn=<DotBackward0>) 0
# tensor(0.6839, grad_fn=<DotBackward0>) 0
# tensor(0.6973, grad_fn=<DotBackward0>) 0
# tensor(1.0603, grad_fn=<DotBackward0>) 1.0
# tensor(0.7058, grad_fn=<DotBackward0>) 0
# tensor(0.8116, grad_fn=<DotBackward0>) 0
# tensor(0.7929, grad_fn=<DotBackward0>) 0
# tensor(0.7025, grad_fn=<DotBackward0>) 0
# tensor(0.6240, grad_fn=<DotBackward0>) 0
# tensor(1.1088, grad_fn=<DotBackward0>) 0
# tensor(0.5733, grad_fn=<DotBackward0>) 0
# tensor(1.2052, grad_fn=<DotBackward0>) 0
# tensor(0.5125, grad_fn=<DotBackward0>) 0
# tensor(0.2526, grad_fn=<DotBackward0>) 0
# tensor(0.6682, grad_fn=<DotBackward0>) 0
# tensor(0.6391, grad_fn=<DotBackward0>) 0
# tensor(1.0266, grad_fn=<DotBackward0>) 0
# tensor(0.8484, grad_fn=<DotBackward0>) 0
# tensor(0.8052, grad_fn=<DotBackward0>) 0
# tensor(1.1453, grad_fn=<DotBackward0>) 0
# tensor(0.5455, grad_fn=<DotBackward0>) 0
# tensor(0.4247, grad_fn=<DotBackward0>) 0
# tensor(0.8462, grad_fn=<DotBackward0>) 0
# tensor(0.7939, grad_fn=<DotBackward0>) 0
# tensor(0.5703, grad_fn=<DotBackward0>) 0
# tensor(0.6322, grad_fn=<DotBackward0>) 0
# tensor(0.7076, grad_fn=<DotBackward0>) 0
# tensor(0.7853, grad_fn=<DotBackward0>) 0
# tensor(0.4984, grad_fn=<DotBackward0>) 0
# tensor(0.5712, grad_fn=<DotBackward0>) 0
# tensor(0.9123, grad_fn=<DotBackward0>) 0
# tensor(1.0557, grad_fn=<DotBackward0>) 0
# tensor(0.6815, grad_fn=<DotBackward0>) 0
# tensor(0.6329, grad_fn=<DotBackward0>) 0
# tensor(0.4405, grad_fn=<DotBackward0>) 0
# tensor(0.8305, grad_fn=<DotBackward0>) 0
# tensor(0.9745, grad_fn=<DotBackward0>) 0
# tensor(0.3351, grad_fn=<DotBackward0>) 0
# tensor(0.9181, grad_fn=<DotBackward0>) 0
# tensor(0.8181, grad_fn=<DotBackward0>) 1.0
# tensor(0.5773, grad_fn=<DotBackward0>) 0
# tensor(0.6560, grad_fn=<DotBackward0>) 0
# tensor(0.9576, grad_fn=<DotBackward0>) 0
# tensor(0.4546, grad_fn=<DotBackward0>) 0
# tensor(0.5515, grad_fn=<DotBackward0>) 0
# tensor(0.6179, grad_fn=<DotBackward0>) 0
# tensor(0.6723, grad_fn=<DotBackward0>) 0
# tensor(0.3652, grad_fn=<DotBackward0>) 0
# tensor(0.8132, grad_fn=<DotBackward0>) 0
# tensor(0.6755, grad_fn=<DotBackward0>) 0
# tensor(0.8499, grad_fn=<DotBackward0>) 0
# tensor(0.4272, grad_fn=<DotBackward0>) 0
# tensor(0.6559, grad_fn=<DotBackward0>) 0
# tensor(0.7826, grad_fn=<DotBackward0>) 0
# tensor(0.2155, grad_fn=<DotBackward0>) 0
# tensor(0.7454, grad_fn=<DotBackward0>) 0
# tensor(0.6317, grad_fn=<DotBackward0>) 0
# tensor(0.6746, grad_fn=<DotBackward0>) 0
# tensor(0.7997, grad_fn=<DotBackward0>) 0
# tensor(0.8119, grad_fn=<DotBackward0>) 0
# tensor(0.6434, grad_fn=<DotBackward0>) 0
# tensor(1.0946, grad_fn=<DotBackward0>) 0
# tensor(0.6920, grad_fn=<DotBackward0>) 0
# tensor(0.7661, grad_fn=<DotBackward0>) 0
# tensor(0.6780, grad_fn=<DotBackward0>) 0
# tensor(0.4444, grad_fn=<DotBackward0>) 0
# tensor(0.7961, grad_fn=<DotBackward0>) 0
# tensor(0.5394, grad_fn=<DotBackward0>) 0
# tensor(0.6162, grad_fn=<DotBackward0>) 0
# tensor(0.5085, grad_fn=<DotBackward0>) 0
# tensor(1.0129, grad_fn=<DotBackward0>) 0
# tensor(0.8864, grad_fn=<DotBackward0>) 0
# tensor(0.9163, grad_fn=<DotBackward0>) 0
# tensor(0.8532, grad_fn=<DotBackward0>) 0
# tensor(0.7368, grad_fn=<DotBackward0>) 0
# tensor(0.5359, grad_fn=<DotBackward0>) 0
# tensor(0.7672, grad_fn=<DotBackward0>) 0
# tensor(1.1526, grad_fn=<DotBackward0>) 0
# tensor(0.8993, grad_fn=<DotBackward0>) 0
# tensor(0.9404, grad_fn=<DotBackward0>) 0
# tensor(0.6316, grad_fn=<DotBackward0>) 0
# tensor(0.4223, grad_fn=<DotBackward0>) 0
# tensor(0.8981, grad_fn=<DotBackward0>) 0
# tensor(0.6420, grad_fn=<DotBackward0>) 0
# tensor(0.6672, grad_fn=<DotBackward0>) 0
# tensor(0.5845, grad_fn=<DotBackward0>) 0
# tensor(0.5586, grad_fn=<DotBackward0>) 0
# tensor(0.6099, grad_fn=<DotBackward0>) 0
# tensor(0.3343, grad_fn=<DotBackward0>) 0
# tensor(0.5942, grad_fn=<DotBackward0>) 0
# tensor(0.5555, grad_fn=<DotBackward0>) 0
# tensor(0.4992, grad_fn=<DotBackward0>) 0
# tensor(0.7406, grad_fn=<DotBackward0>) 0
# tensor(0.5446, grad_fn=<DotBackward0>) 0
# tensor(0.2227, grad_fn=<DotBackward0>) 0
# tensor(0.9868, grad_fn=<DotBackward0>) 0
# tensor(0.7596, grad_fn=<DotBackward0>) 0
# tensor(0.8950, grad_fn=<DotBackward0>) 0
# tensor(0.7386, grad_fn=<DotBackward0>) 0
# tensor(0.4921, grad_fn=<DotBackward0>) 0
# tensor(0.8970, grad_fn=<DotBackward0>) 0
# tensor(0.6084, grad_fn=<DotBackward0>) 0
# tensor(0.8279, grad_fn=<DotBackward0>) 0
# tensor(0.6877, grad_fn=<DotBackward0>) 0
# tensor(0.6590, grad_fn=<DotBackward0>) 0
# tensor(0.7717, grad_fn=<DotBackward0>) 0
# tensor(0.5729, grad_fn=<DotBackward0>) 0
# tensor(0.8132, grad_fn=<DotBackward0>) 0
# tensor(1.0018, grad_fn=<DotBackward0>) 0
# tensor(0.7124, grad_fn=<DotBackward0>) 0
# tensor(0.7970, grad_fn=<DotBackward0>) 0
# tensor(0.6188, grad_fn=<DotBackward0>) 0
# tensor(0.6557, grad_fn=<DotBackward0>) 0
# tensor(0.8090, grad_fn=<DotBackward0>) 0
# tensor(0.6580, grad_fn=<DotBackward0>) 0
# tensor(0.5497, grad_fn=<DotBackward0>) 0
# tensor(0.5340, grad_fn=<DotBackward0>) 0
# tensor(0.4418, grad_fn=<DotBackward0>) 0
# tensor(0.5892, grad_fn=<DotBackward0>) 1.0
# tensor(0.1476, grad_fn=<DotBackward0>) 0
# tensor(0.8227, grad_fn=<DotBackward0>) 0
# tensor(0.6844, grad_fn=<DotBackward0>) 0
# tensor(0.4520, grad_fn=<DotBackward0>) 0
# tensor(0.7350, grad_fn=<DotBackward0>) 0
# tensor(0.6832, grad_fn=<DotBackward0>) 0
# tensor(0.9750, grad_fn=<DotBackward0>) 0
# tensor(0.9153, grad_fn=<DotBackward0>) 0
# tensor(0.9514, grad_fn=<DotBackward0>) 0
# tensor(0.8153, grad_fn=<DotBackward0>) 0
# tensor(0.5162, grad_fn=<DotBackward0>) 0
# tensor(0.8347, grad_fn=<DotBackward0>) 0
# tensor(0.8178, grad_fn=<DotBackward0>) 0
# tensor(0.7436, grad_fn=<DotBackward0>) 0
# tensor(0.7180, grad_fn=<DotBackward0>) 0
# tensor(0.4536, grad_fn=<DotBackward0>) 0
# tensor(0.8012, grad_fn=<DotBackward0>) 0
# tensor(0.4623, grad_fn=<DotBackward0>) 0
# tensor(0.9052, grad_fn=<DotBackward0>) 0
# tensor(0.9767, grad_fn=<DotBackward0>) 0
# tensor(1.0060, grad_fn=<DotBackward0>) 0
# tensor(0.6223, grad_fn=<DotBackward0>) 0
# tensor(0.8136, grad_fn=<DotBackward0>) 0
# tensor(1.0992, grad_fn=<DotBackward0>) 0
# tensor(0.6061, grad_fn=<DotBackward0>) 0
# tensor(0.6302, grad_fn=<DotBackward0>) 0
# tensor(0.8379, grad_fn=<DotBackward0>) 0
# tensor(1.0375, grad_fn=<DotBackward0>) 1.0
# tensor(1.3145, grad_fn=<DotBackward0>) 0
# tensor(0.3828, grad_fn=<DotBackward0>) 0
# tensor(0.8370, grad_fn=<DotBackward0>) 0
# tensor(0.9791, grad_fn=<DotBackward0>) 0
# tensor(0.7972, grad_fn=<DotBackward0>) 0
# tensor(0.5227, grad_fn=<DotBackward0>) 0
# tensor(0.3715, grad_fn=<DotBackward0>) 0
# tensor(0.5238, grad_fn=<DotBackward0>) 0
# tensor(0.7007, grad_fn=<DotBackward0>) 0
# tensor(0.6570, grad_fn=<DotBackward0>) 0
# tensor(0.8845, grad_fn=<DotBackward0>) 0
# tensor(0.8692, grad_fn=<DotBackward0>) 0
# tensor(1.0729, grad_fn=<DotBackward0>) 0
# tensor(0.3482, grad_fn=<DotBackward0>) 0
# tensor(0.5802, grad_fn=<DotBackward0>) 0
# tensor(0.3376, grad_fn=<DotBackward0>) 0
# tensor(0.8081, grad_fn=<DotBackward0>) 0
# tensor(0.5129, grad_fn=<DotBackward0>) 0
# tensor(0.5325, grad_fn=<DotBackward0>) 0
# tensor(0.1046, grad_fn=<DotBackward0>) 0
# tensor(0.2267, grad_fn=<DotBackward0>) 0
# tensor(0.5745, grad_fn=<DotBackward0>) 0
# tensor(0.7760, grad_fn=<DotBackward0>) 0
# tensor(0.6331, grad_fn=<DotBackward0>) 0
# tensor(0.5708, grad_fn=<DotBackward0>) 0
# tensor(0.6817, grad_fn=<DotBackward0>) 0
# tensor(0.7708, grad_fn=<DotBackward0>) 0
# tensor(0.7527, grad_fn=<DotBackward0>) 1.0
# tensor(0.8637, grad_fn=<DotBackward0>) 0
# tensor(0.5860, grad_fn=<DotBackward0>) 0
# tensor(0.7523, grad_fn=<DotBackward0>) 0
# tensor(0.6126, grad_fn=<DotBackward0>) 0
# tensor(0.4091, grad_fn=<DotBackward0>) 0
# tensor(0.6016, grad_fn=<DotBackward0>) 0
# tensor(0.9819, grad_fn=<DotBackward0>) 0
# tensor(0.9877, grad_fn=<DotBackward0>) 0
# tensor(0.5450, grad_fn=<DotBackward0>) 0
# tensor(0.9608, grad_fn=<DotBackward0>) 0
# tensor(0.6200, grad_fn=<DotBackward0>) 0
# tensor(0.6841, grad_fn=<DotBackward0>) 0
# tensor(0.2811, grad_fn=<DotBackward0>) 0
# tensor(0.2804, grad_fn=<DotBackward0>) 0
# tensor(0.4706, grad_fn=<DotBackward0>) 0
# tensor(0.9913, grad_fn=<DotBackward0>) 0
# tensor(0.9755, grad_fn=<DotBackward0>) 0
# tensor(0.4799, grad_fn=<DotBackward0>) 0
# tensor(0.8525, grad_fn=<DotBackward0>) 0
# tensor(0.4630, grad_fn=<DotBackward0>) 0
# tensor(0.6922, grad_fn=<DotBackward0>) 0
# tensor(0.8421, grad_fn=<DotBackward0>) 0
# tensor(0.4530, grad_fn=<DotBackward0>) 0
# tensor(0.8703, grad_fn=<DotBackward0>) 0
# tensor(0.9629, grad_fn=<DotBackward0>) 0
# tensor(0.6810, grad_fn=<DotBackward0>) 0
# tensor(0.7897, grad_fn=<DotBackward0>) 0
# tensor(0.7314, grad_fn=<DotBackward0>) 0
# tensor(1.0607, grad_fn=<DotBackward0>) 0
# tensor(1.0930, grad_fn=<DotBackward0>) 0
# tensor(0.9479, grad_fn=<DotBackward0>) 0
# tensor(0.5546, grad_fn=<DotBackward0>) 0
# tensor(1.0112, grad_fn=<DotBackward0>) 0
# tensor(0.7545, grad_fn=<DotBackward0>) 0
# tensor(0.6793, grad_fn=<DotBackward0>) 0
# tensor(0.6541, grad_fn=<DotBackward0>) 0
# tensor(0.6155, grad_fn=<DotBackward0>) 0
# tensor(0.6849, grad_fn=<DotBackward0>) 1.0
# tensor(0.2588, grad_fn=<DotBackward0>) 0
# tensor(1.2247, grad_fn=<DotBackward0>) 0
# tensor(0.8033, grad_fn=<DotBackward0>) 0
# tensor(0.7409, grad_fn=<DotBackward0>) 0
# tensor(0.5808, grad_fn=<DotBackward0>) 0
# tensor(0.7690, grad_fn=<DotBackward0>) 0
# tensor(0.2629, grad_fn=<DotBackward0>) 0
# tensor(0.8275, grad_fn=<DotBackward0>) 0
# tensor(0.8459, grad_fn=<DotBackward0>) 0
# tensor(0.4208, grad_fn=<DotBackward0>) 0
# tensor(1.0581, grad_fn=<DotBackward0>) 0
# tensor(0.5282, grad_fn=<DotBackward0>) 0
# tensor(0.6934, grad_fn=<DotBackward0>) 0
# tensor(0.7756, grad_fn=<DotBackward0>) 0
# tensor(0.6678, grad_fn=<DotBackward0>) 0
# tensor(1.1339, grad_fn=<DotBackward0>) 0
# tensor(0.6498, grad_fn=<DotBackward0>) 0
# tensor(0.4959, grad_fn=<DotBackward0>) 0
# tensor(0.7022, grad_fn=<DotBackward0>) 0
# tensor(0.9918, grad_fn=<DotBackward0>) 0
# tensor(0.7448, grad_fn=<DotBackward0>) 0
# tensor(0.8871, grad_fn=<DotBackward0>) 0
# tensor(0.8904, grad_fn=<DotBackward0>) 0
# tensor(0.8846, grad_fn=<DotBackward0>) 0
# tensor(0.5873, grad_fn=<DotBackward0>) 0
# tensor(0.8418, grad_fn=<DotBackward0>) 0
# tensor(0.3716, grad_fn=<DotBackward0>) 0
# tensor(0.6403, grad_fn=<DotBackward0>) 0
# tensor(0.5729, grad_fn=<DotBackward0>) 0
# tensor(0.8795, grad_fn=<DotBackward0>) 0
# tensor(0.4819, grad_fn=<DotBackward0>) 0
# tensor(0.8270, grad_fn=<DotBackward0>) 0
# tensor(0.6495, grad_fn=<DotBackward0>) 0
# tensor(0.7677, grad_fn=<DotBackward0>) 0
# tensor(0.8617, grad_fn=<DotBackward0>) 0
# tensor(0.7671, grad_fn=<DotBackward0>) 0
# tensor(0.9356, grad_fn=<DotBackward0>) 0
# tensor(0.8278, grad_fn=<DotBackward0>) 0
# tensor(0.8131, grad_fn=<DotBackward0>) 0
# tensor(0.7596, grad_fn=<DotBackward0>) 0
# tensor(0.8541, grad_fn=<DotBackward0>) 0
# tensor(0.4934, grad_fn=<DotBackward0>) 0
# tensor(0.8441, grad_fn=<DotBackward0>) 0
# tensor(0.6735, grad_fn=<DotBackward0>) 0
# tensor(0.6709, grad_fn=<DotBackward0>) 0
# tensor(0.5167, grad_fn=<DotBackward0>) 0
# tensor(0.6498, grad_fn=<DotBackward0>) 0
# tensor(0.7007, grad_fn=<DotBackward0>) 0
# tensor(0.7295, grad_fn=<DotBackward0>) 0
# tensor(0.5171, grad_fn=<DotBackward0>) 0
# tensor(0.7954, grad_fn=<DotBackward0>) 0
# tensor(0.5898, grad_fn=<DotBackward0>) 0
# tensor(0.3844, grad_fn=<DotBackward0>) 0
# tensor(0.9485, grad_fn=<DotBackward0>) 0
# tensor(0.4672, grad_fn=<DotBackward0>) 0
# tensor(0.5722, grad_fn=<DotBackward0>) 0
# tensor(0.4515, grad_fn=<DotBackward0>) 0
# tensor(0.7232, grad_fn=<DotBackward0>) 0
# tensor(0.6197, grad_fn=<DotBackward0>) 0
# tensor(0.4074, grad_fn=<DotBackward0>) 0
# tensor(0.9072, grad_fn=<DotBackward0>) 0
# tensor(0.6603, grad_fn=<DotBackward0>) 0
# tensor(0.9424, grad_fn=<DotBackward0>) 0
# tensor(0.7809, grad_fn=<DotBackward0>) 0
# tensor(1.0461, grad_fn=<DotBackward0>) 0
# tensor(0.1676, grad_fn=<DotBackward0>) 0
# tensor(0.3950, grad_fn=<DotBackward0>) 0
# tensor(0.3592, grad_fn=<DotBackward0>) 0
# tensor(1.0051, grad_fn=<DotBackward0>) 0
# tensor(0.7148, grad_fn=<DotBackward0>) 0
# tensor(1.0655, grad_fn=<DotBackward0>) 0
# tensor(0.6167, grad_fn=<DotBackward0>) 0
# tensor(0.7584, grad_fn=<DotBackward0>) 0
# tensor(0.7404, grad_fn=<DotBackward0>) 0
# tensor(1.0392, grad_fn=<DotBackward0>) 0
# tensor(0.6108, grad_fn=<DotBackward0>) 0
# tensor(0.1697, grad_fn=<DotBackward0>) 0
# tensor(0.5667, grad_fn=<DotBackward0>) 0
# tensor(0.6749, grad_fn=<DotBackward0>) 0
# tensor(0.9677, grad_fn=<DotBackward0>) 0
# tensor(0.2006, grad_fn=<DotBackward0>) 0
# tensor(0.3608, grad_fn=<DotBackward0>) 0
# tensor(0.8868, grad_fn=<DotBackward0>) 0
# tensor(0.8693, grad_fn=<DotBackward0>) 0
# tensor(0.4583, grad_fn=<DotBackward0>) 0
# tensor(0.4960, grad_fn=<DotBackward0>) 0
# tensor(0.5735, grad_fn=<DotBackward0>) 0
# tensor(1.0997, grad_fn=<DotBackward0>) 0
# tensor(0.8711, grad_fn=<DotBackward0>) 0
# tensor(0.4257, grad_fn=<DotBackward0>) 0
# tensor(0.5992, grad_fn=<DotBackward0>) 0
# tensor(0.6914, grad_fn=<DotBackward0>) 0
# tensor(0.8816, grad_fn=<DotBackward0>) 0
# tensor(1.1314, grad_fn=<DotBackward0>) 0
# tensor(0.6156, grad_fn=<DotBackward0>) 0
# tensor(0.6780, grad_fn=<DotBackward0>) 0
# tensor(0.6955, grad_fn=<DotBackward0>) 0
# tensor(0.9789, grad_fn=<DotBackward0>) 0
# tensor(0.2417, grad_fn=<DotBackward0>) 0
# tensor(0.6402, grad_fn=<DotBackward0>) 0
# tensor(0.9789, grad_fn=<DotBackward0>) 0
# tensor(0.4332, grad_fn=<DotBackward0>) 0
# tensor(0.7875, grad_fn=<DotBackward0>) 0
# tensor(0.9781, grad_fn=<DotBackward0>) 0
# tensor(0.7155, grad_fn=<DotBackward0>) 0
# tensor(0.7129, grad_fn=<DotBackward0>) 0
# tensor(0.4668, grad_fn=<DotBackward0>) 0
# tensor(0.6776, grad_fn=<DotBackward0>) 0
# tensor(0.4234, grad_fn=<DotBackward0>) 0
# tensor(0.5616, grad_fn=<DotBackward0>) 0
# tensor(0.5703, grad_fn=<DotBackward0>) 0
# tensor(0.3926, grad_fn=<DotBackward0>) 0
# tensor(0.7529, grad_fn=<DotBackward0>) 0
# tensor(0.4894, grad_fn=<DotBackward0>) 0
# tensor(0.6208, grad_fn=<DotBackward0>) 0
# tensor(0.8672, grad_fn=<DotBackward0>) 0
# tensor(0.5267, grad_fn=<DotBackward0>) 0
# tensor(0.3593, grad_fn=<DotBackward0>) 0
# tensor(0.7099, grad_fn=<DotBackward0>) 0
# tensor(0.5883, grad_fn=<DotBackward0>) 0
# tensor(0.9410, grad_fn=<DotBackward0>) 0
# tensor(0.4118, grad_fn=<DotBackward0>) 0
# tensor(0.5887, grad_fn=<DotBackward0>) 0
# tensor(1.0760, grad_fn=<DotBackward0>) 0
# tensor(0.4805, grad_fn=<DotBackward0>) 0
# tensor(0.4584, grad_fn=<DotBackward0>) 0
# tensor(0.5580, grad_fn=<DotBackward0>) 0
# tensor(0.8238, grad_fn=<DotBackward0>) 0
# tensor(0.9257, grad_fn=<DotBackward0>) 0
# tensor(0.9655, grad_fn=<DotBackward0>) 0
# tensor(0.5174, grad_fn=<DotBackward0>) 0
# tensor(0.6723, grad_fn=<DotBackward0>) 0
# tensor(1.0250, grad_fn=<DotBackward0>) 0
# tensor(0.3539, grad_fn=<DotBackward0>) 0
# tensor(0.5883, grad_fn=<DotBackward0>) 0
# tensor(0.6531, grad_fn=<DotBackward0>) 0
# tensor(0.3435, grad_fn=<DotBackward0>) 0
# tensor(0.8047, grad_fn=<DotBackward0>) 0
# tensor(0.8464, grad_fn=<DotBackward0>) 0
# tensor(0.6163, grad_fn=<DotBackward0>) 0
# tensor(0.9403, grad_fn=<DotBackward0>) 0
# tensor(0.6601, grad_fn=<DotBackward0>) 0
# tensor(0.3033, grad_fn=<DotBackward0>) 0
# tensor(0.5253, grad_fn=<DotBackward0>) 0
# tensor(0.1595, grad_fn=<DotBackward0>) 0
# tensor(0.4322, grad_fn=<DotBackward0>) 0
# tensor(0.9654, grad_fn=<DotBackward0>) 0
# tensor(0.6539, grad_fn=<DotBackward0>) 0
# tensor(0.9249, grad_fn=<DotBackward0>) 0
# tensor(0.4087, grad_fn=<DotBackward0>) 0
# tensor(0.9358, grad_fn=<DotBackward0>) 0
# tensor(0.5708, grad_fn=<DotBackward0>) 0
# tensor(0.9772, grad_fn=<DotBackward0>) 0
# tensor(0.2434, grad_fn=<DotBackward0>) 0
# tensor(0.3932, grad_fn=<DotBackward0>) 0
# tensor(0.8509, grad_fn=<DotBackward0>) 0
# tensor(0.9852, grad_fn=<DotBackward0>) 0
# tensor(0.8521, grad_fn=<DotBackward0>) 0
# tensor(0.5387, grad_fn=<DotBackward0>) 0
# tensor(0.5543, grad_fn=<DotBackward0>) 0
# tensor(0.5859, grad_fn=<DotBackward0>) 0
# tensor(0.4988, grad_fn=<DotBackward0>) 0
# tensor(1.0630, grad_fn=<DotBackward0>) 0
# tensor(0.4020, grad_fn=<DotBackward0>) 0
# tensor(0.8706, grad_fn=<DotBackward0>) 0
# tensor(0.5565, grad_fn=<DotBackward0>) 0
# tensor(0.8186, grad_fn=<DotBackward0>) 0
# tensor(1.1111, grad_fn=<DotBackward0>) 0
# tensor(0.5622, grad_fn=<DotBackward0>) 1.0
# tensor(0.5971, grad_fn=<DotBackward0>) 0
# tensor(1.2317, grad_fn=<DotBackward0>) 0
# tensor(0.6791, grad_fn=<DotBackward0>) 0
# tensor(0.5411, grad_fn=<DotBackward0>) 0
# tensor(0.5180, grad_fn=<DotBackward0>) 0
# tensor(0.8597, grad_fn=<DotBackward0>) 0
# tensor(0.6861, grad_fn=<DotBackward0>) 0
# tensor(0.8603, grad_fn=<DotBackward0>) 0
# tensor(0.7578, grad_fn=<DotBackward0>) 0
# tensor(0.5841, grad_fn=<DotBackward0>) 0
# tensor(0.6174, grad_fn=<DotBackward0>) 0
# tensor(0.8765, grad_fn=<DotBackward0>) 0
# tensor(0.6092, grad_fn=<DotBackward0>) 0
# tensor(0.7110, grad_fn=<DotBackward0>) 0
# tensor(0.9296, grad_fn=<DotBackward0>) 0
# tensor(0.8575, grad_fn=<DotBackward0>) 0
# tensor(0.9952, grad_fn=<DotBackward0>) 0
# tensor(0.7859, grad_fn=<DotBackward0>) 0
# tensor(0.6828, grad_fn=<DotBackward0>) 0
# tensor(0.5777, grad_fn=<DotBackward0>) 0
# tensor(0.5815, grad_fn=<DotBackward0>) 0
# tensor(0.9672, grad_fn=<DotBackward0>) 0
# tensor(0.4594, grad_fn=<DotBackward0>) 0
# tensor(0.5210, grad_fn=<DotBackward0>) 0
# tensor(1.0007, grad_fn=<DotBackward0>) 0
# tensor(0.7917, grad_fn=<DotBackward0>) 0
# tensor(0.8304, grad_fn=<DotBackward0>) 0
# tensor(0.5124, grad_fn=<DotBackward0>) 0
# tensor(0.9927, grad_fn=<DotBackward0>) 0
# tensor(0.9339, grad_fn=<DotBackward0>) 0
# tensor(0.6591, grad_fn=<DotBackward0>) 0
# tensor(0.6404, grad_fn=<DotBackward0>) 0
# tensor(0.9475, grad_fn=<DotBackward0>) 0
# tensor(0.7767, grad_fn=<DotBackward0>) 0
# tensor(1.0097, grad_fn=<DotBackward0>) 0
# tensor(0.9229, grad_fn=<DotBackward0>) 0
# tensor(0.9508, grad_fn=<DotBackward0>) 0
# tensor(0.5886, grad_fn=<DotBackward0>) 0
# tensor(0.3693, grad_fn=<DotBackward0>) 0
# tensor(0.8133, grad_fn=<DotBackward0>) 0
# tensor(0.4193, grad_fn=<DotBackward0>) 0
# tensor(0.9375, grad_fn=<DotBackward0>) 0
# tensor(0.7240, grad_fn=<DotBackward0>) 0
# tensor(0.5590, grad_fn=<DotBackward0>) 0
# tensor(0.4979, grad_fn=<DotBackward0>) 0
# tensor(0.6580, grad_fn=<DotBackward0>) 0
# tensor(0.6450, grad_fn=<DotBackward0>) 0
# tensor(0.6261, grad_fn=<DotBackward0>) 0
# tensor(0.5816, grad_fn=<DotBackward0>) 0
# tensor(0.7077, grad_fn=<DotBackward0>) 0
# tensor(0.6638, grad_fn=<DotBackward0>) 0
# tensor(0.9197, grad_fn=<DotBackward0>) 0
# tensor(0.4600, grad_fn=<DotBackward0>) 0
# tensor(1.1670, grad_fn=<DotBackward0>) 0
# tensor(1.0194, grad_fn=<DotBackward0>) 0
# tensor(0.8042, grad_fn=<DotBackward0>) 0
# tensor(0.7292, grad_fn=<DotBackward0>) 0
# tensor(0.8539, grad_fn=<DotBackward0>) 0
# tensor(0.5185, grad_fn=<DotBackward0>) 0
# tensor(0.4107, grad_fn=<DotBackward0>) 0
# tensor(0.7265, grad_fn=<DotBackward0>) 0
# tensor(0.7086, grad_fn=<DotBackward0>) 0
# tensor(0.7327, grad_fn=<DotBackward0>) 0
# tensor(0.8171, grad_fn=<DotBackward0>) 0
# tensor(0.2708, grad_fn=<DotBackward0>) 0
# tensor(0.5360, grad_fn=<DotBackward0>) 0
# tensor(0.8308, grad_fn=<DotBackward0>) 0
# tensor(1.1054, grad_fn=<DotBackward0>) 0
# tensor(0.9332, grad_fn=<DotBackward0>) 0
# tensor(0.5957, grad_fn=<DotBackward0>) 0
# tensor(0.8347, grad_fn=<DotBackward0>) 0
# tensor(0.7152, grad_fn=<DotBackward0>) 0
# tensor(0.8623, grad_fn=<DotBackward0>) 0
# tensor(0.4567, grad_fn=<DotBackward0>) 0
# tensor(0.4310, grad_fn=<DotBackward0>) 0
# tensor(0.9574, grad_fn=<DotBackward0>) 0
# tensor(0.8468, grad_fn=<DotBackward0>) 0
# tensor(0.5460, grad_fn=<DotBackward0>) 0
# tensor(0.4411, grad_fn=<DotBackward0>) 0
# tensor(0.9094, grad_fn=<DotBackward0>) 0
# tensor(0.7677, grad_fn=<DotBackward0>) 0
# tensor(0.7716, grad_fn=<DotBackward0>) 0
# tensor(0.7911, grad_fn=<DotBackward0>) 0
# tensor(0.6332, grad_fn=<DotBackward0>) 0
# tensor(0.4322, grad_fn=<DotBackward0>) 0
# tensor(0.7387, grad_fn=<DotBackward0>) 0
# tensor(0.5709, grad_fn=<DotBackward0>) 0
# tensor(0.4574, grad_fn=<DotBackward0>) 0
# tensor(0.7010, grad_fn=<DotBackward0>) 0
# tensor(0.7328, grad_fn=<DotBackward0>) 0
# tensor(0.8911, grad_fn=<DotBackward0>) 0
# tensor(0.9046, grad_fn=<DotBackward0>) 0
# tensor(0.9889, grad_fn=<DotBackward0>) 0
# tensor(0.6889, grad_fn=<DotBackward0>) 0
# tensor(0.8388, grad_fn=<DotBackward0>) 0
# tensor(0.5456, grad_fn=<DotBackward0>) 0
# tensor(0.3326, grad_fn=<DotBackward0>) 0
# tensor(0.9444, grad_fn=<DotBackward0>) 0
# tensor(0.4190, grad_fn=<DotBackward0>) 0
# tensor(0.5967, grad_fn=<DotBackward0>) 0
# tensor(0.4318, grad_fn=<DotBackward0>) 0
# tensor(0.8748, grad_fn=<DotBackward0>) 0
# tensor(0.9379, grad_fn=<DotBackward0>) 0
# tensor(0.4005, grad_fn=<DotBackward0>) 0
# tensor(0.5225, grad_fn=<DotBackward0>) 1.0
# tensor(0.5570, grad_fn=<DotBackward0>) 0
# tensor(0.8407, grad_fn=<DotBackward0>) 0
# tensor(0.9068, grad_fn=<DotBackward0>) 0
# tensor(0.4377, grad_fn=<DotBackward0>) 0
# tensor(0.7321, grad_fn=<DotBackward0>) 0
# tensor(0.9028, grad_fn=<DotBackward0>) 0
# tensor(0.8742, grad_fn=<DotBackward0>) 0
# tensor(0.2106, grad_fn=<DotBackward0>) 0
# tensor(0.4221, grad_fn=<DotBackward0>) 0
# tensor(0.6842, grad_fn=<DotBackward0>) 0
# tensor(0.6708, grad_fn=<DotBackward0>) 0
# tensor(0.6139, grad_fn=<DotBackward0>) 0
# tensor(0.5899, grad_fn=<DotBackward0>) 0
# tensor(1.0552, grad_fn=<DotBackward0>) 0
# tensor(0.8840, grad_fn=<DotBackward0>) 0
# tensor(0.9368, grad_fn=<DotBackward0>) 0
# tensor(0.7455, grad_fn=<DotBackward0>) 0
# tensor(0.5965, grad_fn=<DotBackward0>) 0
# tensor(0.7891, grad_fn=<DotBackward0>) 0
# tensor(0.5174, grad_fn=<DotBackward0>) 0
# tensor(0.9963, grad_fn=<DotBackward0>) 0
# tensor(0.6126, grad_fn=<DotBackward0>) 0
# tensor(0.5953, grad_fn=<DotBackward0>) 0
# tensor(0.7452, grad_fn=<DotBackward0>) 0
# tensor(0.6024, grad_fn=<DotBackward0>) 0
# tensor(0.8887, grad_fn=<DotBackward0>) 0
# tensor(1.0546, grad_fn=<DotBackward0>) 0
# tensor(0.3995, grad_fn=<DotBackward0>) 0
# tensor(0.2718, grad_fn=<DotBackward0>) 0
# tensor(1.1228, grad_fn=<DotBackward0>) 0
# tensor(0.6260, grad_fn=<DotBackward0>) 0
# tensor(0.4028, grad_fn=<DotBackward0>) 0
# tensor(0.7020, grad_fn=<DotBackward0>) 0
# tensor(0.7249, grad_fn=<DotBackward0>) 0
# tensor(1.0096, grad_fn=<DotBackward0>) 0
# tensor(0.1390, grad_fn=<DotBackward0>) 0
# tensor(0.6201, grad_fn=<DotBackward0>) 0
# tensor(0.8088, grad_fn=<DotBackward0>) 0
# tensor(0.4360, grad_fn=<DotBackward0>) 0
# tensor(0.7884, grad_fn=<DotBackward0>) 0
# tensor(0.3958, grad_fn=<DotBackward0>) 0
# tensor(1.0501, grad_fn=<DotBackward0>) 0
# tensor(0.6175, grad_fn=<DotBackward0>) 1.0
# tensor(0.5534, grad_fn=<DotBackward0>) 0
# tensor(0.5645, grad_fn=<DotBackward0>) 0
# tensor(0.6386, grad_fn=<DotBackward0>) 0
# tensor(0.7684, grad_fn=<DotBackward0>) 0
# tensor(0.4459, grad_fn=<DotBackward0>) 0
# tensor(0.6227, grad_fn=<DotBackward0>) 0
# tensor(1.1003, grad_fn=<DotBackward0>) 0
# tensor(0.7322, grad_fn=<DotBackward0>) 0
# tensor(0.7615, grad_fn=<DotBackward0>) 0
# tensor(0.6648, grad_fn=<DotBackward0>) 0
# tensor(1.1313, grad_fn=<DotBackward0>) 0
# tensor(0.8264, grad_fn=<DotBackward0>) 0
# tensor(0.8735, grad_fn=<DotBackward0>) 0
# tensor(0.2621, grad_fn=<DotBackward0>) 0
# tensor(0.5835, grad_fn=<DotBackward0>) 0
# tensor(0.7616, grad_fn=<DotBackward0>) 0
# tensor(1.0361, grad_fn=<DotBackward0>) 0
# tensor(0.7253, grad_fn=<DotBackward0>) 0
# tensor(0.4812, grad_fn=<DotBackward0>) 0
# tensor(0.7532, grad_fn=<DotBackward0>) 1.0
# tensor(0.2988, grad_fn=<DotBackward0>) 0
# tensor(0.6347, grad_fn=<DotBackward0>) 0
# tensor(1.0027, grad_fn=<DotBackward0>) 0
# tensor(0.7069, grad_fn=<DotBackward0>) 0
# tensor(0.7676, grad_fn=<DotBackward0>) 0
# tensor(0.5492, grad_fn=<DotBackward0>) 0
# tensor(0.3613, grad_fn=<DotBackward0>) 0
# tensor(0.9244, grad_fn=<DotBackward0>) 1.0
# tensor(0.6470, grad_fn=<DotBackward0>) 0
# tensor(0.4637, grad_fn=<DotBackward0>) 0
# tensor(0.6040, grad_fn=<DotBackward0>) 0
# tensor(0.7083, grad_fn=<DotBackward0>) 0
# tensor(0.9920, grad_fn=<DotBackward0>) 0
# tensor(0.4924, grad_fn=<DotBackward0>) 0
# tensor(0.4297, grad_fn=<DotBackward0>) 0
# tensor(0.6316, grad_fn=<DotBackward0>) 0
# tensor(0.6910, grad_fn=<DotBackward0>) 0
# tensor(0.1583, grad_fn=<DotBackward0>) 0
# tensor(0.6820, grad_fn=<DotBackward0>) 0
# tensor(0.5422, grad_fn=<DotBackward0>) 0
# tensor(0.6929, grad_fn=<DotBackward0>) 0
# ...
# tensor(0.4293, grad_fn=<DotBackward0>) 1.0
# tensor(0.1022, grad_fn=<DotBackward0>) 0
# tensor(0.8061, grad_fn=<DotBackward0>) 0
# tensor(0.6011, grad_fn=<DotBackward0>) 0
# tensor(0.3300, grad_fn=<DotBackward0>) 0
# tensor(0.8197, grad_fn=<DotBackward0>) 0
# tensor(0.1255, grad_fn=<DotBackward0>) 0
# tensor(0.6663, grad_fn=<DotBackward0>) 0
# tensor(0.6611, grad_fn=<DotBackward0>) 0
# tensor(0.4590, grad_fn=<DotBackward0>) 1.0
# tensor(0.5450, grad_fn=<DotBackward0>) 0
# tensor(0.5001, grad_fn=<DotBackward0>) 0
# tensor(0.6304, grad_fn=<DotBackward0>) 1.0
# tensor(0.3722, grad_fn=<DotBackward0>) 1.0
# tensor(0.9501, grad_fn=<DotBackward0>) 1.0
# tensor(0.6473, grad_fn=<DotBackward0>) 0
# tensor(0.6797, grad_fn=<DotBackward0>) 0
# tensor(0.6308, grad_fn=<DotBackward0>) 1.0
# tensor(0.7313, grad_fn=<DotBackward0>) 0
# tensor(0.2691, grad_fn=<DotBackward0>) 0
# tensor(0.7268, grad_fn=<DotBackward0>) 0
# tensor(0.7657, grad_fn=<DotBackward0>) 0
# tensor(0.7829, grad_fn=<DotBackward0>) 0
# tensor(0.8125, grad_fn=<DotBackward0>) 0
# tensor(1.1047, grad_fn=<DotBackward0>) 0
# tensor(0.3756, grad_fn=<DotBackward0>) 0
# tensor(1.1005, grad_fn=<DotBackward0>) 0
# tensor(0.8949, grad_fn=<DotBackward0>) 0
# tensor(0.4797, grad_fn=<DotBackward0>) 0
# tensor(0.6249, grad_fn=<DotBackward0>) 0
# tensor(1.0856, grad_fn=<DotBackward0>) 0
# tensor(1.0213, grad_fn=<DotBackward0>) 0
# tensor(0.6355, grad_fn=<DotBackward0>) 0
# tensor(0.4013, grad_fn=<DotBackward0>) 0
# tensor(0.7237, grad_fn=<DotBackward0>) 0
# tensor(0.8166, grad_fn=<DotBackward0>) 0
# tensor(0.6834, grad_fn=<DotBackward0>) 0
# tensor(0.7317, grad_fn=<DotBackward0>) 0
# tensor(0.5857, grad_fn=<DotBackward0>) 0
# tensor(1.1042, grad_fn=<DotBackward0>) 0
# tensor(0.6233, grad_fn=<DotBackward0>) 0
# tensor(0.9933, grad_fn=<DotBackward0>) 0
# tensor(0.7458, grad_fn=<DotBackward0>) 0
# tensor(0.9537, grad_fn=<DotBackward0>) 1.0
# tensor(0.5376, grad_fn=<DotBackward0>) 0
# tensor(1.1455, grad_fn=<DotBackward0>) 0
# tensor(0.9165, grad_fn=<DotBackward0>) 0
# tensor(0.6552, grad_fn=<DotBackward0>) 0
# tensor(1.0886, grad_fn=<DotBackward0>) 0
# tensor(0.6747, grad_fn=<DotBackward0>) 0
# tensor(1.1103, grad_fn=<DotBackward0>) 0
# tensor(0.4935, grad_fn=<DotBackward0>) 0
# tensor(0.6097, grad_fn=<DotBackward0>) 0
# tensor(0.7576, grad_fn=<DotBackward0>) 0
# tensor(0.6708, grad_fn=<DotBackward0>) 1.0
# tensor(0.6814, grad_fn=<DotBackward0>) 0
# tensor(0.6877, grad_fn=<DotBackward0>) 0
# tensor(1.0956, grad_fn=<DotBackward0>) 0
# tensor(0.9257, grad_fn=<DotBackward0>) 0
# tensor(0.8991, grad_fn=<DotBackward0>) 0
# tensor(0.7433, grad_fn=<DotBackward0>) 1.0
# tensor(0.7945, grad_fn=<DotBackward0>) 0
# tensor(0.6654, grad_fn=<DotBackward0>) 0
# tensor(0.6515, grad_fn=<DotBackward0>) 1.0
# tensor(0.4401, grad_fn=<DotBackward0>) 0
# tensor(0.6570, grad_fn=<DotBackward0>) 0
# tensor(1.0890, grad_fn=<DotBackward0>) 0
# tensor(0.4335, grad_fn=<DotBackward0>) 1.0
# tensor(0.6029, grad_fn=<DotBackward0>) 0
# tensor(0.4476, grad_fn=<DotBackward0>) 0
# tensor(0.5423, grad_fn=<DotBackward0>) 1.0
# tensor(0.2572, grad_fn=<DotBackward0>) 1.0
# tensor(0.3796, grad_fn=<DotBackward0>) 0
# tensor(0.8565, grad_fn=<DotBackward0>) 0
# tensor(1.1105, grad_fn=<DotBackward0>) 0
# tensor(0.3832, grad_fn=<DotBackward0>) 0
# tensor(0.5191, grad_fn=<DotBackward0>) 1.0
# tensor(0.6902, grad_fn=<DotBackward0>) 0
# tensor(0.8487, grad_fn=<DotBackward0>) 0
# tensor(0.3764, grad_fn=<DotBackward0>) 1.0
# tensor(0.6011, grad_fn=<DotBackward0>) 0
# tensor(0.3165, grad_fn=<DotBackward0>) 0
# tensor(0.5607, grad_fn=<DotBackward0>) 0
# tensor(0.8704, grad_fn=<DotBackward0>) 0
# tensor(0.6285, grad_fn=<DotBackward0>) 0
# tensor(0.6243, grad_fn=<DotBackward0>) 0
# tensor(0.8240, grad_fn=<DotBackward0>) 0
# tensor(0.9767, grad_fn=<DotBackward0>) 0
# tensor(0.9280, grad_fn=<DotBackward0>) 0
# tensor(0.6251, grad_fn=<DotBackward0>) 0
# tensor(0.7054, grad_fn=<DotBackward0>) 0
# tensor(0.5106, grad_fn=<DotBackward0>) 0
# tensor(0.6919, grad_fn=<DotBackward0>) 0
# tensor(0.4462, grad_fn=<DotBackward0>) 0
# tensor(0.4186, grad_fn=<DotBackward0>) 0
# tensor(0.3724, grad_fn=<DotBackward0>) 0
# tensor(0.6180, grad_fn=<DotBackward0>) 0
# tensor(0.8048, grad_fn=<DotBackward0>) 0
# tensor(0.8003, grad_fn=<DotBackward0>) 0
# tensor(0.8588, grad_fn=<DotBackward0>) 0
# tensor(0.7925, grad_fn=<DotBackward0>) 0
# tensor(0.9054, grad_fn=<DotBackward0>) 0
# tensor(1.1906, grad_fn=<DotBackward0>) 0
# tensor(0.7645, grad_fn=<DotBackward0>) 0
# tensor(0.4460, grad_fn=<DotBackward0>) 0
# tensor(0.9998, grad_fn=<DotBackward0>) 0
# tensor(0.9111, grad_fn=<DotBackward0>) 0
# tensor(0.7938, grad_fn=<DotBackward0>) 0
# tensor(0.5123, grad_fn=<DotBackward0>) 0
# tensor(0.8782, grad_fn=<DotBackward0>) 0
# tensor(0.8360, grad_fn=<DotBackward0>) 0
# tensor(0.3198, grad_fn=<DotBackward0>) 0
# tensor(0.8015, grad_fn=<DotBackward0>) 0
# tensor(0.3194, grad_fn=<DotBackward0>) 0
# tensor(0.5346, grad_fn=<DotBackward0>) 0
# tensor(0.6980, grad_fn=<DotBackward0>) 0
# tensor(0.8807, grad_fn=<DotBackward0>) 0
# tensor(0.9692, grad_fn=<DotBackward0>) 0
# tensor(0.8495, grad_fn=<DotBackward0>) 0
# tensor(0.6579, grad_fn=<DotBackward0>) 0
# tensor(0.5874, grad_fn=<DotBackward0>) 0
# tensor(0.4928, grad_fn=<DotBackward0>) 0
# tensor(0.7108, grad_fn=<DotBackward0>) 0
# tensor(0.1872, grad_fn=<DotBackward0>) 0
# tensor(0.6307, grad_fn=<DotBackward0>) 0
# tensor(0.4090, grad_fn=<DotBackward0>) 0
# tensor(0.5803, grad_fn=<DotBackward0>) 0
# tensor(0.5362, grad_fn=<DotBackward0>) 0
# tensor(0.6583, grad_fn=<DotBackward0>) 0
# tensor(0.9985, grad_fn=<DotBackward0>) 1.0
# tensor(0.3736, grad_fn=<DotBackward0>) 0
# tensor(0.7094, grad_fn=<DotBackward0>) 0
# tensor(0.7945, grad_fn=<DotBackward0>) 0
# tensor(0.9539, grad_fn=<DotBackward0>) 0
# tensor(0.7198, grad_fn=<DotBackward0>) 0
# tensor(0.8829, grad_fn=<DotBackward0>) 0
# tensor(0.4629, grad_fn=<DotBackward0>) 0
# tensor(0.6327, grad_fn=<DotBackward0>) 1.0
# tensor(0.4231, grad_fn=<DotBackward0>) 1.0
# tensor(0.7041, grad_fn=<DotBackward0>) 0
# tensor(0.9555, grad_fn=<DotBackward0>) 0
# tensor(0.9893, grad_fn=<DotBackward0>) 0
# tensor(0.4849, grad_fn=<DotBackward0>) 1.0
# tensor(1.0566, grad_fn=<DotBackward0>) 0
# tensor(0.2602, grad_fn=<DotBackward0>) 0
# tensor(0.6699, grad_fn=<DotBackward0>) 0
# tensor(0.9468, grad_fn=<DotBackward0>) 0
# tensor(0.4724, grad_fn=<DotBackward0>) 0
# tensor(0.8019, grad_fn=<DotBackward0>) 0
# tensor(0.5640, grad_fn=<DotBackward0>) 0
# tensor(0.9726, grad_fn=<DotBackward0>) 0
# tensor(0.1376, grad_fn=<DotBackward0>) 0
# tensor(0.7924, grad_fn=<DotBackward0>) 0
# tensor(0.8257, grad_fn=<DotBackward0>) 0
# tensor(0.4575, grad_fn=<DotBackward0>) 0
# tensor(1.2187, grad_fn=<DotBackward0>) 0
# tensor(0.4978, grad_fn=<DotBackward0>) 0
# tensor(0.8627, grad_fn=<DotBackward0>) 0
# tensor(0.7893, grad_fn=<DotBackward0>) 0
# tensor(0.8322, grad_fn=<DotBackward0>) 0
# tensor(0.7015, grad_fn=<DotBackward0>) 0
# tensor(1.0145, grad_fn=<DotBackward0>) 0
# tensor(0.7813, grad_fn=<DotBackward0>) 0
# tensor(0.9149, grad_fn=<DotBackward0>) 0
# tensor(0.6420, grad_fn=<DotBackward0>) 0
# tensor(0.3508, grad_fn=<DotBackward0>) 0
# tensor(1.3252, grad_fn=<DotBackward0>) 0
# tensor(0.6785, grad_fn=<DotBackward0>) 0
# tensor(0.5974, grad_fn=<DotBackward0>) 0
# tensor(0.7832, grad_fn=<DotBackward0>) 0
# tensor(0.4784, grad_fn=<DotBackward0>) 0
# tensor(0.9299, grad_fn=<DotBackward0>) 0
# tensor(1.1249, grad_fn=<DotBackward0>) 0
# tensor(0.4449, grad_fn=<DotBackward0>) 1.0
# tensor(0.7713, grad_fn=<DotBackward0>) 0
# tensor(0.2710, grad_fn=<DotBackward0>) 0
# tensor(0.8401, grad_fn=<DotBackward0>) 0
# tensor(0.5157, grad_fn=<DotBackward0>) 0
# tensor(0.7678, grad_fn=<DotBackward0>) 0
# tensor(0.5036, grad_fn=<DotBackward0>) 1.0
# tensor(0.9792, grad_fn=<DotBackward0>) 0
# tensor(0.8953, grad_fn=<DotBackward0>) 0
# tensor(0.7017, grad_fn=<DotBackward0>) 0
# tensor(0.7530, grad_fn=<DotBackward0>) 0
# tensor(0.4682, grad_fn=<DotBackward0>) 0
# tensor(0.8145, grad_fn=<DotBackward0>) 0
# tensor(0.3266, grad_fn=<DotBackward0>) 0
# tensor(0.9417, grad_fn=<DotBackward0>) 0
# tensor(0.6387, grad_fn=<DotBackward0>) 0
# tensor(0.4718, grad_fn=<DotBackward0>) 0
# tensor(0.3439, grad_fn=<DotBackward0>) 0
# tensor(1.0074, grad_fn=<DotBackward0>) 0
# tensor(0.9779, grad_fn=<DotBackward0>) 0
# tensor(0.5285, grad_fn=<DotBackward0>) 0
# tensor(0.9340, grad_fn=<DotBackward0>) 0
# tensor(0.6147, grad_fn=<DotBackward0>) 0
# tensor(0.6224, grad_fn=<DotBackward0>) 0
# tensor(1.0273, grad_fn=<DotBackward0>) 1.0
# tensor(1.1532, grad_fn=<DotBackward0>) 0
# tensor(0.5258, grad_fn=<DotBackward0>) 0
# tensor(0.4460, grad_fn=<DotBackward0>) 0
# tensor(0.8189, grad_fn=<DotBackward0>) 0
# tensor(0.5101, grad_fn=<DotBackward0>) 0
# tensor(0.4727, grad_fn=<DotBackward0>) 0
# tensor(0.6255, grad_fn=<DotBackward0>) 0
# tensor(0.6180, grad_fn=<DotBackward0>) 0
# tensor(1.1427, grad_fn=<DotBackward0>) 0
# tensor(0.4947, grad_fn=<DotBackward0>) 0
# tensor(0.5482, grad_fn=<DotBackward0>) 0
# tensor(0.2709, grad_fn=<DotBackward0>) 0
# tensor(0.7148, grad_fn=<DotBackward0>) 0
# tensor(0.4820, grad_fn=<DotBackward0>) 1.0
# tensor(1.2439, grad_fn=<DotBackward0>) 0
# tensor(0.8903, grad_fn=<DotBackward0>) 0
# tensor(0.4495, grad_fn=<DotBackward0>) 0
# tensor(0.8615, grad_fn=<DotBackward0>) 1.0
# tensor(0.8626, grad_fn=<DotBackward0>) 0
# tensor(1.1040, grad_fn=<DotBackward0>) 0
# tensor(0.8667, grad_fn=<DotBackward0>) 0
# tensor(1.1658, grad_fn=<DotBackward0>) 0
# tensor(0.3030, grad_fn=<DotBackward0>) 0
# tensor(0.7380, grad_fn=<DotBackward0>) 0
# tensor(0.9747, grad_fn=<DotBackward0>) 0
# tensor(0.9996, grad_fn=<DotBackward0>) 0
# tensor(1.1549, grad_fn=<DotBackward0>) 1.0
# tensor(1.0105, grad_fn=<DotBackward0>) 0
# tensor(0.8195, grad_fn=<DotBackward0>) 0
# tensor(1.0331, grad_fn=<DotBackward0>) 0
# tensor(0.6750, grad_fn=<DotBackward0>) 0
# tensor(0.6887, grad_fn=<DotBackward0>) 0
# tensor(0.6843, grad_fn=<DotBackward0>) 0
# tensor(0.9651, grad_fn=<DotBackward0>) 0
# tensor(0.6362, grad_fn=<DotBackward0>) 0
# tensor(0.8412, grad_fn=<DotBackward0>) 0
# tensor(0.7015, grad_fn=<DotBackward0>) 0
# tensor(0.8144, grad_fn=<DotBackward0>) 0
# tensor(0.6283, grad_fn=<DotBackward0>) 0
# tensor(0.6011, grad_fn=<DotBackward0>) 0
# tensor(0.9711, grad_fn=<DotBackward0>) 0
# tensor(0.9337, grad_fn=<DotBackward0>) 0
# tensor(0.7594, grad_fn=<DotBackward0>) 0
# tensor(0.5500, grad_fn=<DotBackward0>) 0
# tensor(0.7593, grad_fn=<DotBackward0>) 0
# tensor(0.3667, grad_fn=<DotBackward0>) 0
# tensor(0.4096, grad_fn=<DotBackward0>) 0
# tensor(0.7601, grad_fn=<DotBackward0>) 0
# tensor(0.6831, grad_fn=<DotBackward0>) 0
# tensor(0.7715, grad_fn=<DotBackward0>) 0
# tensor(0.7873, grad_fn=<DotBackward0>) 1.0
# tensor(0.9527, grad_fn=<DotBackward0>) 0
# tensor(0.7176, grad_fn=<DotBackward0>) 0
# tensor(1.0030, grad_fn=<DotBackward0>) 0
# tensor(0.2151, grad_fn=<DotBackward0>) 0
# tensor(0.8510, grad_fn=<DotBackward0>) 0
# tensor(0.4076, grad_fn=<DotBackward0>) 0
# tensor(0.7480, grad_fn=<DotBackward0>) 0
# tensor(0.6453, grad_fn=<DotBackward0>) 0
# tensor(0.8572, grad_fn=<DotBackward0>) 0
# tensor(0.4481, grad_fn=<DotBackward0>) 0
# tensor(0.7062, grad_fn=<DotBackward0>) 0
# tensor(0.6408, grad_fn=<DotBackward0>) 0
# tensor(0.6554, grad_fn=<DotBackward0>) 0
# tensor(0.5161, grad_fn=<DotBackward0>) 0
# tensor(0.4429, grad_fn=<DotBackward0>) 1.0
# tensor(0.9116, grad_fn=<DotBackward0>) 0
# tensor(0.7226, grad_fn=<DotBackward0>) 0
# tensor(0.8004, grad_fn=<DotBackward0>) 0
# tensor(0.4834, grad_fn=<DotBackward0>) 0
# tensor(0.6803, grad_fn=<DotBackward0>) 0
# tensor(0.4974, grad_fn=<DotBackward0>) 0
# tensor(0.4882, grad_fn=<DotBackward0>) 0
# tensor(0.9292, grad_fn=<DotBackward0>) 0
# tensor(0.5356, grad_fn=<DotBackward0>) 0
# tensor(0.5938, grad_fn=<DotBackward0>) 0
# tensor(0.7362, grad_fn=<DotBackward0>) 0
# tensor(0.5819, grad_fn=<DotBackward0>) 0
# tensor(0.3433, grad_fn=<DotBackward0>) 0
# tensor(0.6826, grad_fn=<DotBackward0>) 0
# tensor(0.7256, grad_fn=<DotBackward0>) 0
# tensor(1.0100, grad_fn=<DotBackward0>) 0
# tensor(0.8570, grad_fn=<DotBackward0>) 0
# tensor(0.9149, grad_fn=<DotBackward0>) 0
# tensor(0.5474, grad_fn=<DotBackward0>) 0
# tensor(0.9500, grad_fn=<DotBackward0>) 0
# tensor(0.6599, grad_fn=<DotBackward0>) 0
# tensor(0.6377, grad_fn=<DotBackward0>) 0
# tensor(0.6755, grad_fn=<DotBackward0>) 0
# tensor(0.4831, grad_fn=<DotBackward0>) 0
# tensor(0.4430, grad_fn=<DotBackward0>) 0
# tensor(1.0256, grad_fn=<DotBackward0>) 1.0
# tensor(0.6155, grad_fn=<DotBackward0>) 1.0
# tensor(0.6679, grad_fn=<DotBackward0>) 0
# tensor(0.2914, grad_fn=<DotBackward0>) 0
# tensor(0.7256, grad_fn=<DotBackward0>) 0
# tensor(0.5983, grad_fn=<DotBackward0>) 0
# tensor(0.6900, grad_fn=<DotBackward0>) 0
# tensor(0.3189, grad_fn=<DotBackward0>) 0
# tensor(0.6020, grad_fn=<DotBackward0>) 0
# tensor(0.5616, grad_fn=<DotBackward0>) 0
# tensor(0.9205, grad_fn=<DotBackward0>) 0
# tensor(0.6612, grad_fn=<DotBackward0>) 0
# tensor(0.5027, grad_fn=<DotBackward0>) 0
# tensor(0.3570, grad_fn=<DotBackward0>) 0
# tensor(0.4958, grad_fn=<DotBackward0>) 0
# tensor(0.5721, grad_fn=<DotBackward0>) 0
# tensor(0.7066, grad_fn=<DotBackward0>) 0
# tensor(0.8269, grad_fn=<DotBackward0>) 0
# tensor(0.9336, grad_fn=<DotBackward0>) 0
# tensor(0.4640, grad_fn=<DotBackward0>) 0
# tensor(0.4998, grad_fn=<DotBackward0>) 0
# tensor(0.5856, grad_fn=<DotBackward0>) 0
# tensor(0.6692, grad_fn=<DotBackward0>) 0
# tensor(0.6964, grad_fn=<DotBackward0>) 0
# tensor(0.6423, grad_fn=<DotBackward0>) 0
# tensor(0.5752, grad_fn=<DotBackward0>) 0
# tensor(0.6714, grad_fn=<DotBackward0>) 0
# tensor(0.2942, grad_fn=<DotBackward0>) 0
# tensor(1.2496, grad_fn=<DotBackward0>) 0
# tensor(0.8776, grad_fn=<DotBackward0>) 0
# tensor(0.5587, grad_fn=<DotBackward0>) 0
# tensor(0.7702, grad_fn=<DotBackward0>) 0
# tensor(0.3970, grad_fn=<DotBackward0>) 0
# tensor(0.9110, grad_fn=<DotBackward0>) 0
# tensor(0.9041, grad_fn=<DotBackward0>) 1.0
# tensor(0.7099, grad_fn=<DotBackward0>) 0
# tensor(0.8209, grad_fn=<DotBackward0>) 0
# tensor(0.1509, grad_fn=<DotBackward0>) 0
# tensor(0.6858, grad_fn=<DotBackward0>) 1.0
# tensor(0.6968, grad_fn=<DotBackward0>) 1.0
# tensor(1.0975, grad_fn=<DotBackward0>) 1.0
# tensor(0.7885, grad_fn=<DotBackward0>) 0
# tensor(0.7546, grad_fn=<DotBackward0>) 0
# tensor(0.8687, grad_fn=<DotBackward0>) 1.0
# tensor(1.0762, grad_fn=<DotBackward0>) 0
# tensor(0.7760, grad_fn=<DotBackward0>) 0
# tensor(0.5121, grad_fn=<DotBackward0>) 0
# tensor(0.6142, grad_fn=<DotBackward0>) 0
# tensor(0.9004, grad_fn=<DotBackward0>) 0
# tensor(0.7617, grad_fn=<DotBackward0>) 0
# tensor(0.7555, grad_fn=<DotBackward0>) 0
# tensor(0.4994, grad_fn=<DotBackward0>) 0
# tensor(0.6186, grad_fn=<DotBackward0>) 0
# tensor(0.8769, grad_fn=<DotBackward0>) 0
# tensor(0.5841, grad_fn=<DotBackward0>) 0
# tensor(0.9187, grad_fn=<DotBackward0>) 0
# tensor(0.4114, grad_fn=<DotBackward0>) 0
# tensor(0.2426, grad_fn=<DotBackward0>) 0
# tensor(0.6486, grad_fn=<DotBackward0>) 0
# tensor(1.0299, grad_fn=<DotBackward0>) 1.0
# tensor(0.7034, grad_fn=<DotBackward0>) 0
# tensor(0.2971, grad_fn=<DotBackward0>) 0
# tensor(0.6207, grad_fn=<DotBackward0>) 1.0
# tensor(0.9308, grad_fn=<DotBackward0>) 0
# tensor(0.7425, grad_fn=<DotBackward0>) 0
# tensor(0.5720, grad_fn=<DotBackward0>) 0
# tensor(0.7235, grad_fn=<DotBackward0>) 0
# tensor(0.1540, grad_fn=<DotBackward0>) 0
# tensor(0.6834, grad_fn=<DotBackward0>) 0
# tensor(0.8239, grad_fn=<DotBackward0>) 0
# tensor(0.6475, grad_fn=<DotBackward0>) 0
# tensor(0.8466, grad_fn=<DotBackward0>) 0
# tensor(0.5716, grad_fn=<DotBackward0>) 0
# tensor(0.3788, grad_fn=<DotBackward0>) 0
# tensor(0.9886, grad_fn=<DotBackward0>) 0
# tensor(1.1319, grad_fn=<DotBackward0>) 0
# tensor(1.0783, grad_fn=<DotBackward0>) 0
# tensor(0.4630, grad_fn=<DotBackward0>) 0
# tensor(0.7540, grad_fn=<DotBackward0>) 0
# tensor(0.6972, grad_fn=<DotBackward0>) 0
# tensor(0.3180, grad_fn=<DotBackward0>) 0
# tensor(0.6649, grad_fn=<DotBackward0>) 0
# tensor(0.7786, grad_fn=<DotBackward0>) 0
# tensor(1.1470, grad_fn=<DotBackward0>) 0
# tensor(0.5902, grad_fn=<DotBackward0>) 0
# tensor(0.6823, grad_fn=<DotBackward0>) 0
# tensor(0.9942, grad_fn=<DotBackward0>) 0
# tensor(0.9889, grad_fn=<DotBackward0>) 0
# tensor(0.4961, grad_fn=<DotBackward0>) 0
# tensor(0.4420, grad_fn=<DotBackward0>) 0
# tensor(0.5810, grad_fn=<DotBackward0>) 0
# tensor(0.8594, grad_fn=<DotBackward0>) 0
# Result: Parameter containing:
# tensor([[0.5328, 0.4964, 0.3080],
#         [0.2721, 0.2061, 0.6631],
#         [0.7827, 0.8941, 0.2678],
#         ...,
#         [0.0431, 0.4300, 0.4528],
#         [0.2796, 0.2596, 0.7196],
#         [0.4617, 0.7126, 0.6624]], requires_grad=True)

# %%
class Polynomial3(torch.nn.Module):
    def __init__(self):
        """
        In the constructor we instantiate four parameters and assign them as
        member parameters.
        """
        super().__init__()
        self.moviematrix = torch.nn.Parameter(torch.rand(7363, 3))

    def forward(self, m1, m2):
        """
        In the forward function we accept a Tensor of input data and we must return
        a Tensor of output data. We can use Modules defined in the constructor as
        well as arbitrary operators on Tensors.
        """
        a = self.moviematrix[m1]
        b = self.moviematrix[m2]
        c = torch.matmul(a,b)
        #print("c",c)
        #print("m1",m1)
        return c

    def string(self):
        """
        Just like any class in Python, you can also define custom method on PyTorch modules
        """
        return str(self.moviematrix)

def my_loss_fn(y_pred, y_actual):
      d = y_pred - y_actual
      d = d*d
      return d

def plot_loss(optim_var, lr_value):
    model = Polynomial3()

    criterion = my_loss_fn

    #lr_value = 1e-3 or 1e-6
    optimizer = torch.optim.SGD(model.parameters(), lr=lr_value)
    if optim_var == 1:
      optimizer = torch.optim.Adam(model.parameters(), lr=lr_value)
      #print("set adam")

    len_matrix = df3.shape[0]
    epoch = 1
    len_matrix = 500

    loss_4graph = y=np.empty(len_matrix*len_matrix)
    itel_loca =  0
    for i in range(epoch):
      for p in range(len_matrix):
          for q in range (len_matrix):
              # Forward pass: Compute predicted y by passing x to the model
              y_pred = model(p,q)

              # Compute and print loss
              abc = df3.iat[p,q]
              if np.isnan(abc):
                abc=0
              loss = criterion(y_pred, abc)
              #print(p, loss.item())
              loss_4graph[itel_loca] = loss.item()
              itel_loca = itel_loca + 1

              # Zero gradients, perform a backward pass, and update the weights.
              optimizer.zero_grad()
              loss.backward()
              optimizer.step()
    return loss_4graph

loss1 = plot_loss(0, 1e-6)
plt.plot(loss1)
plt.title("Loss for SGD with LR = 1e-6")
plt.show()

loss2 = plot_loss(0, 1e-3)
plt.plot(loss2)
plt.title("Loss for SGD with LR = 1e-3")
plt.show()

loss3 = plot_loss(1, 1e-6)
plt.plot(loss3)
plt.title("Loss for Adam with LR = 1e-6")
plt.show()

loss4 = plot_loss(1, 1e-3)
plt.plot(loss4)
plt.title("Loss for Adam with LR = 1e-3")
plt.show()

# %% [markdown]
# **PART C:** Recommend top 10 movies (not vectors or indices but movie names) given movies
#
# (a) Apollo 13,
#
# (b) Toy Story, and
#
# (c) Home Alone.

# %% [markdown]
#  **Describe your recommendation strategy**
#
# -- The model predicts the number of users that liked two movies provided as input. Therefore strategy to recommend is noted as follows
#
# Step 1 : predict the number of users that would like every combination of Input Movie and every other movie. Note that the model uses movie index, therefore the movie ID is converted to movie index before performing this step.
#
# Step 2 : Find the movies with top 10 largest predicted predictions from step 1.
#
# **Do the recommendations change when you change learning rates or optimizers? Why or why not?**
#
# -- Yes, the recommendations would change as the learning rate/optimizers change. If there's a decrease in the learning rate, the gradient descent occurs much slowly, if the learning rate is too high it will upset the local minima.

# %%
import heapq

movies = pd.read_csv('movies.csv')

def get_top10(name):
    spec_movie = movies[movies['title'] == name]
    movie_id = spec_movie.iloc[0]['movieId']
    movie_index = 0

    i=0
    for row in df3.index: 
        if row == movie_id:
          movie_index = i
          break
        i = i + 1

    y=np.empty(df3.shape[0])
    for i in range(df3.shape[0]):
        y[i] = model(movie_index, i)

    #top_ten = np.argpartition(y,10)[:10]
    top_ten = heapq.nlargest(10, range(len(y)), y.__getitem__)
    x = heapq.nlargest(10, y)
    print(x)
    print("Top 10 Recommendations for ", name)
    for i in range(10):
      refer_index = df3.index[top_ten[i]]
      x = movies[movies['movieId'] == refer_index]
      print(x)

get_top10('Apollo 13 (1995)')
print("#"*100)
get_top10('Toy Story (1995)')
print("#"*100)
get_top10('Home Alone (1990)')
# Out:
# [0.9771456718444824, 0.956233024597168, 0.951681911945343, 0.9453678131103516, 0.9419395923614502, 0.9384504556655884, 0.935857892036438, 0.9340354204177856, 0.9305469989776611, 0.9279581308364868]
# Top 10 Recommendations for  Apollo 13 (1995)
#      movieId                title                    genres
# 314      356  Forrest Gump (1994)  Comedy|Drama|Romance|War
#       movieId                               title  genres
# 3903     5481  Austin Powers in Goldmember (2002)  Comedy
#       movieId                                    title                genres
# 6338    48997  Perfume: The Story of a Murderer (2006)  Crime|Drama|Thriller
#     movieId                    title       genres
# 86       97  Hate (Haine, La) (1995)  Crime|Drama
#     movieId          title       genres
# 15       16  Casino (1995)  Crime|Drama
#       movieId             title  genres
# 2129     2829  Muse, The (1999)  Comedy
#       movieId              title                          genres
# 9437   166635  Passengers (2016)  Adventure|Drama|Romance|Sci-Fi
#      movieId                 title                            genres
# 418      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
#       movieId  ...                            genres
# 6460    52435  ...  Animation|Comedy|Fantasy|Musical
#
# [1 rows x 3 columns]
#       movieId        title                 genres
# 3416     4645  Cure (1997)  Crime|Horror|Thriller
# ####################################################################################################
# [1.280191421508789, 1.27860689163208, 1.2606996297836304, 1.2558577060699463, 1.2528226375579834, 1.2521222829818726, 1.2480278015136719, 1.2445417642593384, 1.244511604309082, 1.2347495555877686]
# Top 10 Recommendations for  Toy Story (1995)
#      movieId                 title                            genres
# 418      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
#       movieId              title                          genres
# 9437   166635  Passengers (2016)  Adventure|Drama|Romance|Sci-Fi
#       movieId                               title  genres
# 3903     5481  Austin Powers in Goldmember (2002)  Comedy
#       movieId                            title       genres
# 5084     8011  Weather Underground, The (2002)  Documentary
#       movieId  ...                            genres
# 6460    52435  ...  Animation|Comedy|Fantasy|Musical
#
# [1 rows x 3 columns]
#       movieId                                    title                genres
# 6338    48997  Perfume: The Story of a Murderer (2006)  Crime|Drama|Thriller
#      movieId                                   title                     genres
# 599      745  Wallace & Gromit: A Close Shave (1995)  Animation|Children|Comedy
#      movieId             title          genres
# 106      122  Boomerang (1992)  Comedy|Romance
#     movieId          title       genres
# 15       16  Casino (1995)  Crime|Drama
#      movieId                          title                    genres
# 790     1033  Fox and the Hound, The (1981)  Animation|Children|Drama
# ####################################################################################################
# [0.8386186361312866, 0.8375288844108582, 0.8205835223197937, 0.8143666982650757, 0.812000036239624, 0.8118757009506226, 0.8114770650863647, 0.8039337396621704, 0.8028314113616943, 0.8020291328430176]
# Top 10 Recommendations for  Home Alone (1990)
#       movieId              title                          genres
# 9437   166635  Passengers (2016)  Adventure|Drama|Romance|Sci-Fi
#      movieId                 title                            genres
# 418      480  Jurassic Park (1993)  Action|Adventure|Sci-Fi|Thriller
#       movieId                            title       genres
# 5084     8011  Weather Underground, The (2002)  Documentary
#       movieId                 title                         genres
# 6331    48780  Prestige, The (2006)  Drama|Mystery|Sci-Fi|Thriller
#       movieId  ...                            genres
# 6460    52435  ...  Animation|Comedy|Fantasy|Musical
#
# [1 rows x 3 columns]
#       movieId                               title  genres
# 3903     5481  Austin Powers in Goldmember (2002)  Comedy
#      movieId             title          genres
# 106      122  Boomerang (1992)  Comedy|Romance
#       movieId        title                         genres
# 7014    68237  Moon (2009)  Drama|Mystery|Sci-Fi|Thriller
#       movieId                                    title                genres
# 6338    48997  Perfume: The Story of a Murderer (2006)  Crime|Drama|Thriller
#      movieId                                   title                     genres
# 599      745  Wallace & Gromit: A Close Shave (1995)  Animation|Children|Comedy
